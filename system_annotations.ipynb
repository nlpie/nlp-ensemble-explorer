# %%
# annotation class for UIMA systems
class AnnotationSystems(object):
    """
    CAS XMI Annotations of interest
    
    """
    
    def __init__(self):
        
        """ 
        annotation base types
        """
        
        self.biomedicus_dir = "biomedicus_out/"
        self.biomedicus_types = ["biomedicus.v2.UmlsConcept",
                                 "biomedicus.v2.Negated",
                                 "biomedicus.v2.Acronym"]
        
        
        self.clamp_dir = "clamp_out/"
        self.clamp_types = ["edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA",
                            "edu.uth.clamp.nlp.typesystem.ClampRelationUIMA"]
        
        
        self.ctakes_dir = "ctakes_out/"
        self.ctakes_types = ["org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention",
                             "org.apache.ctakes.typesystem.type.textsem.MedicationMention",
                             "org.apache.ctakes.typesystem.type.textsem.ProcedureMention",
                             #"org.apache.ctakes.typesystem.type.refsem.UmlsConcept",
                             "org.apache.ctakes.typesystem.type.textsem.SignSymptomMention",
                             "org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention"]
        
        self.metamap_dir = "metamap_out/"
        self.metamap_types = ["org.metamap.uima.ts.Candidate",
                              "org.metamap.uima.ts.CuiConcept",
                              "org.metamap.uima.ts.Negation"]
                
       
    def get_system_type(self, system):
        
        """
        return system types
        """
        
        if system == "biomedicus":
            view = "Analysis"
            
        else:
            view = "_InitialView"

        if system == 'biomedicus':
            types = self.biomedicus_types
            output = self.biomedicus_dir

        elif system == 'clamp':
            types = self.clamp_types
            output = self.clamp_dir

        elif system == 'ctakes':
            types = self.ctakes_types
            output = self.ctakes_dir

        elif system == 'metamap':
            types = self.metamap_types
            output = self.metamap_dir
            
        return types, view, output
    
annSys = AnnotationSystems()

# extract attributes from cas Annotation object
def get_attribs(v):
    attribs = []
    for sentence in v:
        #print(sentence)
        for s in sentence.__dir__():
            if '__' not in s:
                if s not in attribs:
                    #print(s)
                    attribs.append(s)
                else:
                    break

    return attribs

def get_cols_to_keep(system, t):
    
    if system == 'biomedicus':
        
        # umlsconcept
        if 'Umls' in t:
            cols_to_keep = ['begin', 'confidence', 'cui', 'end', 'source', 'sui', 'tui',
                            'type', 'xmiID', 'system', 'note_id', 'corpus',
                            'filename']

        # acronym
        if 'Acronym' in t:
            cols_to_keep = ['begin', 'end', 'hasSpaceAfter', 'score', 'text', 'type',
                            'xmiID', 'system', 'note_id', 'corpus', 'filename']

        # negated
        if 'Negated' in t:
            cols_to_keep = ['begin', 'cueTerms', 'end', 'type', 'xmiID',
                           'system', 'note_id', 'corpus', 'filename']
        
    elif system == 'clamp':
        #NE uima
        if 'NameEntityUIMA' in t:
            cols_to_keep = ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin',
                           'cui', 'end', 'semanticTag', 'type', 
                           'xmiID', 'system', 'note_id', 'corpus', 'filename']

        # relation uima: TODO -> deal with named tuples!
        if 'Relation' in t:
            cols_to_keep = ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo',
                           'semanticTag', 'type', 'xmiID', 'system', 'note_id',
                           'corpus', 'filename']
        
    elif system == 'ctakes':
        # disease
        if 'Disease' in t:
            cols_to_keep = ['alleviatingFactor', 'associatedSignSymptom', 'begin', 'bodyLaterality',
                           'bodyLocation', 'bodySide', 'conditional', 'confidence', 'course',
                           'discoveryTechnique', 'duration', 'end', 'endTime', 'event',
                           'exacerbatingFactor', 'generic', 'historyOf', 'id',
                           'ontologyConceptArr', 'polarity', 'relativeTemporalContext', 'severity',
                           'startTime', 'subject', 'type', 'typeID', 'uncertainty',
                           'xmiID', 'system', 'note_id', 'corpus', 'filename']

        # medication
        if 'Medication' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'discoveryTechnique', 'end',
                           'endDate', 'event', 'generic', 'historyOf', 'id', 'medicationAllergy',
                           'medicationDosage', 'medicationDuration', 'medicationForm',
                           'medicationFrequency', 'medicationRoute', 'medicationStatusChange',
                           'medicationStrength', 'ontologyConceptArr', 'polarity',
                           'relativeTemporalContext', 'startDate', 'subject', 'type',
                           'typeID', 'uncertainty', 'xmiID', 'system',
                           'note_id', 'corpus', 'filename']

        # proc
        if 'Procedure' in t:
            cols_to_keep = ['begin', 'bodyLaterality', 'bodyLocation', 'bodySide', 'conditional',
                           'confidence', 'discoveryTechnique', 'duration', 'end', 'endTime',
                           'event', 'generic', 'historyOf', 'id', 'method', 'ontologyConceptArr',
                           'polarity', 'procedureDevice', 'relativeTemporalContext', 
                           'startTime', 'subject', 'type', 'typeID', 'uncertainty',
                           'xmiID', 'system', 'note_id', 'corpus', 'filename']

        # sign
        if 'SignSymptom' in t:
            cols_to_keep = ['alleviatingFactor', 'begin', 'bodyLaterality', 'bodyLocation',
                           'bodySide', 'conditional', 'confidence', 'course', 'discoveryTechnique',
                           'duration', 'end', 'endTime', 'event', 'exacerbatingFactor', 'generic',
                           'historyOf', 'id', 'ontologyConceptArr', 'polarity',
                           'relativeTemporalContext', 'severity', 'startTime', 'subject',
                           'type', 'typeID', 'uncertainty', 'xmiID', 'system',
                           'note_id', 'corpus', 'filename']

        # anatomy
        if 'Anatomical' in t:
            cols_to_keep = ['begin', 'bodyLaterality', 'bodySide', 'conditional', 'confidence',
                           'discoveryTechnique', 'end', 'entity', 'generic', 'historyOf', 'id',
                           'ontologyConceptArr', 'polarity', 'subject', 'type', 'typeID',
                           'uncertainty', 'xmiID', 'system', 'note_id',
                           'corpus', 'filename']
        
    elif system == 'metamap':
        #candidate
        if 'Candidate' in t:
            cols_to_keep = ['begin', 'concept', 'cui', 'end', 'head', 'matchMap', 'matchedwords',
                           'overmatch', 'preferred', 'score', 'semanticTypes', 'sources',
                           'spans', 'type', 'xmiID', 'system', 'note_id',
                           'corpus', 'filename']

        #cuiconcept
        if 'CuiConcept' in t:
            cols_to_keep = ['id', 'negExConcept', 'negExCui', 'type', 'xmiID',
                           'system', 'note_id', 'corpus', 'filename']

        #negation
        if 'Negation' in t:
            cols_to_keep = ['begin', 'cuiConcepts', 'end', 'id', 'ncSpans', 'negTrigger', 'negType',
                           'ntSpans', 'type', 'xmiID', 'system',
                           'note_id', 'corpus', 'filename']
    
    else:
        cols_to_keep = []

    return cols_to_keep

# %%
def init_cassis(system, typesystem):
   
    #tic=timeit.default_timer() 

    print(system)

    # types for metamap

    if system == 'metamap':
        t = typesystem.create_type(name='org.apache.uima.examples.SourceDocumentInformation', supertypeName='uima.tcas.Annotation')
        typesystem.add_feature(t, name='uri', rangeTypeName='uima.cas.String')
        typesystem.add_feature(t, name="offsetInSource", rangeTypeName="uima.cas.Integer")
        typesystem.add_feature(t, name="documentSize", rangeTypeName="uima.cas.Integer")
        typesystem.add_feature(t, name="lastSegment", rangeTypeName="uima.cas.Integer")

    # features for ctakes

    if system == 'ctakes':
        t = typesystem.get_type('org.apache.ctakes.typesystem.type.structured.Metadata')
        typesystem.add_feature(t, name='patientIdentifier', rangeTypeName='uima.cas.String')
        
        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.SignSymptomMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.MedicationMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.ProcedureMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

# %%
#%%time
# parse system annotations
def main():
    import os, glob
    import pymysql
    import pandas as pd
    import json
    #from superjson import json
    
    from sqlalchemy.engine import create_engine
    from sqlalchemy.sql import text
    from cassis import load_typesystem, load_cas_from_xmi

    # connection string
    engine = create_engine('mysql+pymysql://gms:nej123@localhost/concepts', pool_pre_ping=True)
    #systems = ["metamap", "ctakes", "biomedicus", "clamp"]
    systems = ["clamp"] #, "ctakes", "biomedicus", "clamp"]
    
    corpora = ["mipacq"]
    parse_to_sql = True
    
    i = 0
    if parse_to_sql:
        
        for corpus in corpora:

            for system in systems:

                print("SYSTEM:", system)
                

                types, view_, output = annSys.get_system_type(system)
                
                dir_test = '/Users/gms/development/nlp/nlpie/scripts/jupyter/ensembling/typesystems/' + system + '/'

                with open(dir_test + 'TypeSystem.xml', 'rb') as f:
                    typesystem = load_typesystem(f)
                
                init_cassis(system, typesystem)
                # parse directory

                if corpus in ["i2b2", "mipacq"]:
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/ensembling-u01/' + corpus + '/rerun-november-2019/' +  system + '_out/' #data_to_analyze/all/'
                
                elif corpus == 'fairview_annotations':
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/ensembling-u01/' + corpus + '/system_annotations/' #data_to_analyze/all/'
                    
                else:
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/mimic/'

                for fname in glob.glob(directory_to_parse + '/*.xmi'):

                    file = os.path.basename(fname)
                    u = file.split('.')[0]

                    print(u, file)

                    # load cas
                    with open(directory_to_parse + file, 'rb') as f:
                        cas = load_cas_from_xmi(f, typesystem=typesystem)

                    # load cas view
                    view = cas.get_view(view_)

                    # sofa -> db
                    def write_sofa(u):
                        d = {}
                        d["note_id"] = str(u)
                        d["sofa"] = view.sofa_string
                        d["corpus"] = corpus

                        # does it exist?
                        if engine.dialect.has_table(engine, "sofas"):
                            sql = text("SELECT * FROM test.sofas WHERE note_id = :e1")
                            resp = engine.execute(sql, e1=u).fetchall()
                        else:
                            resp = []

                        if len(resp) == 0:            
                            pd.DataFrame(d, index=[0]).to_sql("sofas", engine, if_exists="append")  

                    #write_sofa(u)

                    for t in types:
                        
                        cols_to_keep = get_cols_to_keep(system, t)
                        
                        print(t, cols_to_keep)
                        
                        attribs = get_attribs(view.select(t))
                        annotation_type = t
                        x = t.split('.')
                        table_name = system[0:3] + '_' + x[0] + '_' + x[len(x)-1]

                        # Annotation object -> dataframe
                        def get_df(v, attribs):
                        #def get_df(v, attribs, t, table_name):
                            d = {}
                            df = pd.DataFrame()

                            # only parse if type exists in file
                            if view.select(t):
                                for sentence in view.select(t):
                                    
                                    #print(sentence)
                                    
                                    for i in range(len(attribs)):
                                        key = attribs[i]
                                        val = sentence.__getattribute__(attribs[i])
                                        
                                        if key in ['entFrom', 'entTo']:
                                            
                                            if val.attribute:
                                                attribute = json.loads(val.attribute)
                                            else:
                                                attribute = None
                                                
                                            val = json.dumps({"begin": val.begin, "end": val.end, "cui": val.cui, "attribute": attribute})
                                            
                                            print(key, val)
                                    
                                        if isinstance(val, list):
                                            val = ' '.join(map(str,val)) # flatten list to space delimited variable
                  
                                        d[key] = val
                                        if i == len(attribs) - 1:

                                            # compress object for db storage
                                            #d["attributes"] = json.dumps(d, compress=True)

                                            frames = [ df, pd.DataFrame(d, index=[0]) ]
                                            df = pd.concat(frames, ignore_index=True)

                            df["system"] = system
                            df["type"] = annotation_type
                            df["note_id"] = u
                            df["corpus"] = corpus
                            df["filename"] = fname
                            #df.to_sql(table_name, engine, if_exists="append")  
                            return df

                        annotations = get_df(view.select(t), attribs)

                        # write to database

                        if not annotations.empty:
                            #print(annotations[0:2])
                            #print(annotations.columns)
                            annotations = annotations[cols_to_keep]
                            annotations.to_sql(table_name, engine, if_exists="append") 
   
    # write out annotations for non-cui tables
    else:
        
        sys_ann_other = pd.DataFrame()
        for system in systems:
                
            types, view_, output = annSys.get_system_type(system)
            print("SYSTEM:", system)
           
            for t in types:

                x = t.split('.')
                table_name = system[0:3] + '_' + x[0] + '_' + x[len(x)-1]

                sql = "SELECT * FROM test." + table_name 
                df = pd.read_sql(sql, engine)

                cols_to_keep = ['begin', 'end', 'type', 'system', 'note_id', 'corpus', 'filename']
                #print(system, t, table_name, list(df[cols_to_keep].columns.values))
                
                frames = [ sys_ann_other, df[cols_to_keep] ]
                sys_ann_other = pd.concat(frames, ignore_index=True)
        
        print(sys_ann_other.drop_duplicates())
        sys_ann_other.drop_duplicates().to_csv('/Users/gms/development/nlp/nlpie/data/amia-2019/output/analytical_mipacq_others.csv')

    print("done!")

if __name__ == '__main__':
    main()
# Out:
# SYSTEM: clamp
# clamp
# 527982345 527982345.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 92, "end": 105, "cui": null, "attribute": {"sentence_prob": 0.146, "concept_prob": 0.706}}
# entTo {"begin": 96, "end": 100, "cui": null, "attribute": null}
# entFrom {"begin": 232, "end": 245, "cui": null, "attribute": {"sentence_prob": 0.146, "concept_prob": 0.826}}
# entTo {"begin": 229, "end": 231, "cui": null, "attribute": null}
# entFrom {"begin": 232, "end": 245, "cui": null, "attribute": {"sentence_prob": 0.146, "concept_prob": 0.826}}
# entTo {"begin": 236, "end": 240, "cui": null, "attribute": null}
# entFrom {"begin": 498, "end": 510, "cui": null, "attribute": {"sentence_prob": 0.415, "concept_prob": 0.989}}
# entTo {"begin": 482, "end": 497, "cui": null, "attribute": null}
# entFrom {"begin": 578, "end": 614, "cui": null, "attribute": {"sentence_prob": 0.415, "concept_prob": 1.0}}
# entTo {"begin": 608, "end": 614, "cui": null, "attribute": null}
# entFrom {"begin": 578, "end": 614, "cui": null, "attribute": {"sentence_prob": 0.415, "concept_prob": 1.0}}
# entTo {"begin": 588, "end": 603, "cui": null, "attribute": null}
# entFrom {"begin": 899, "end": 911, "cui": null, "attribute": {"sentence_prob": 0.072, "concept_prob": 0.684}}
# entTo {"begin": 879, "end": 892, "cui": null, "attribute": null}
# entFrom {"begin": 1708, "end": 1728, "cui": "C0037090 SNOMEDCT_US[161920001]", "attribute": {"sentence_prob": "0.575", "concept_prob": "0.998", "umlsCuiDesc": "Signs and Symptoms, Respiratory"}}
# entTo {"begin": 1708, "end": 1719, "cui": null, "attribute": null}
# 4130154172-4 4130154172-4.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 67, "end": 91, "cui": null, "attribute": {"sentence_prob": 0.897, "concept_prob": 0.999}}
# entTo {"begin": 64, "end": 66, "cui": null, "attribute": null}
# entFrom {"begin": 67, "end": 91, "cui": null, "attribute": {"sentence_prob": 0.897, "concept_prob": 0.999}}
# entTo {"begin": 79, "end": 83, "cui": null, "attribute": null}
# entFrom {"begin": 317, "end": 344, "cui": null, "attribute": {"sentence_prob": 0.587, "concept_prob": 0.588}}
# entTo {"begin": 332, "end": 336, "cui": null, "attribute": null}
# entFrom {"begin": 1005, "end": 1015, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "1.0", "concept_prob": "1.0", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 1002, "end": 1004, "cui": null, "attribute": null}
# entFrom {"begin": 1005, "end": 1015, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "1.0", "concept_prob": "1.0", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 1005, "end": 1010, "cui": null, "attribute": null}
# entFrom {"begin": 1021, "end": 1026, "cui": "C0687152 SNOMEDCT_US[289114008]", "attribute": {"sentence_prob": "0.999", "concept_prob": "0.999", "umlsCuiDesc": "Does cough"}}
# entTo {"begin": 1018, "end": 1020, "cui": null, "attribute": null}
# entFrom {"begin": 1032, "end": 1036, "cui": "C1956415 SNOMEDCT_US[55442000]", "attribute": {"sentence_prob": "0.989", "concept_prob": "0.989", "umlsCuiDesc": "Paroxysmal nocturnal dyspnea"}}
# entTo {"begin": 1029, "end": 1031, "cui": null, "attribute": null}
# entFrom {"begin": 1042, "end": 1051, "cui": "C0085619 SNOMEDCT_US[62744007]", "attribute": {"sentence_prob": "1.0", "concept_prob": "1.0", "umlsCuiDesc": "Orthopnea"}}
# entTo {"begin": 1039, "end": 1041, "cui": null, "attribute": null}
# entFrom {"begin": 1057, "end": 1069, "cui": "C0581394 SNOMEDCT_US[275319005, 449614009]", "attribute": {"sentence_prob": "0.999", "concept_prob": "1.0", "umlsCuiDesc": "Swollen legs"}}
# entTo {"begin": 1054, "end": 1056, "cui": null, "attribute": null}
# entFrom {"begin": 1057, "end": 1069, "cui": "C0581394 SNOMEDCT_US[275319005, 449614009]", "attribute": {"sentence_prob": "0.999", "concept_prob": "1.0", "umlsCuiDesc": "Swollen legs"}}
# entTo {"begin": 1057, "end": 1060, "cui": null, "attribute": null}
# entFrom {"begin": 1114, "end": 1127, "cui": "C0005911 SNOMEDCT_US[248346009]", "attribute": {"sentence_prob": "0.997", "concept_prob": "0.998", "umlsCuiDesc": "Body Weight Changes"}}
# entTo {"begin": 1100, "end": 1113, "cui": null, "attribute": null}
# entFrom {"begin": 1151, "end": 1163, "cui": "C0024115 SNOMEDCT_US[19829001]", "attribute": {"sentence_prob": "0.537", "concept_prob": "0.98", "umlsCuiDesc": "Lung diseases"}}
# entTo {"begin": 1130, "end": 1132, "cui": null, "attribute": null}
# entFrom {"begin": 1151, "end": 1163, "cui": "C0024115 SNOMEDCT_US[19829001]", "attribute": {"sentence_prob": "0.537", "concept_prob": "0.98", "umlsCuiDesc": "Lung diseases"}}
# entTo {"begin": 1133, "end": 1139, "cui": null, "attribute": null}
# entFrom {"begin": 1151, "end": 1163, "cui": "C0024115 SNOMEDCT_US[19829001]", "attribute": {"sentence_prob": "0.537", "concept_prob": "0.98", "umlsCuiDesc": "Lung diseases"}}
# entTo {"begin": 1151, "end": 1155, "cui": null, "attribute": null}
# entFrom {"begin": 1184, "end": 1190, "cui": "C0004096 SNOMEDCT_US[195967001]", "attribute": {"sentence_prob": "0.537", "concept_prob": "0.981", "umlsCuiDesc": "Asthma"}}
# entTo {"begin": 1130, "end": 1132, "cui": null, "attribute": null}
# entFrom {"begin": 1184, "end": 1190, "cui": "C0004096 SNOMEDCT_US[195967001]", "attribute": {"sentence_prob": "0.537", "concept_prob": "0.981", "umlsCuiDesc": "Asthma"}}
# entTo {"begin": 1133, "end": 1139, "cui": null, "attribute": null}
# entFrom {"begin": 1372, "end": 1410, "cui": null, "attribute": {"sentence_prob": 0.906, "concept_prob": 0.996}}
# entTo {"begin": 1402, "end": 1410, "cui": null, "attribute": null}
# entFrom {"begin": 1484, "end": 1513, "cui": null, "attribute": {"sentence_prob": 0.807, "concept_prob": 0.952}}
# entTo {"begin": 1484, "end": 1490, "cui": null, "attribute": null}
# entFrom {"begin": 1484, "end": 1513, "cui": null, "attribute": {"sentence_prob": 0.807, "concept_prob": 0.952}}
# entTo {"begin": 1511, "end": 1513, "cui": null, "attribute": null}
# entFrom {"begin": 1518, "end": 1536, "cui": "C0007459 SNOMEDCT_US[12454008]", "attribute": {"sentence_prob": "0.992", "concept_prob": "0.998", "umlsCuiDesc": "Cauda equina syndrome with neurogenic bladder"}}
# entTo {"begin": 1529, "end": 1536, "cui": null, "attribute": null}
# entFrom {"begin": 1565, "end": 1595, "cui": null, "attribute": {"sentence_prob": 0.778, "concept_prob": 0.787}}
# entTo {"begin": 1565, "end": 1579, "cui": null, "attribute": null}
# entFrom {"begin": 2255, "end": 2263, "cui": "C0011265 SNOMEDCT_US[12348006]", "attribute": {"sentence_prob": "0.918", "concept_prob": "1.0", "umlsCuiDesc": "Presenile dementia"}}
# entTo {"begin": 2238, "end": 2244, "cui": null, "attribute": null}
# entFrom {"begin": 2265, "end": 2277, "cui": "C0009376 SNOMEDCT_US[68496003]", "attribute": {"sentence_prob": "0.918", "concept_prob": "0.997", "umlsCuiDesc": "Colonic Polyps"}}
# entTo {"begin": 2238, "end": 2244, "cui": null, "attribute": null}
# entFrom {"begin": 2265, "end": 2277, "cui": "C0009376 SNOMEDCT_US[68496003]", "attribute": {"sentence_prob": "0.918", "concept_prob": "0.997", "umlsCuiDesc": "Colonic Polyps"}}
# entTo {"begin": 2265, "end": 2270, "cui": null, "attribute": null}
# entFrom {"begin": 2283, "end": 2315, "cui": null, "attribute": {"sentence_prob": 0.918, "concept_prob": 0.922}}
# entTo {"begin": 2238, "end": 2244, "cui": null, "attribute": null}
# entFrom {"begin": 2283, "end": 2315, "cui": null, "attribute": {"sentence_prob": 0.918, "concept_prob": 0.922}}
# entTo {"begin": 2292, "end": 2307, "cui": null, "attribute": null}
# entFrom {"begin": 2335, "end": 2355, "cui": "C0011860 SNOMEDCT_US[44054006]", "attribute": {"sentence_prob": "0.926", "concept_prob": "1.0", "umlsCuiDesc": "Diabetes Mellitus, Non-Insulin-Dependent"}}
# entTo {"begin": 2318, "end": 2324, "cui": null, "attribute": null}
# entFrom {"begin": 2357, "end": 2369, "cui": "C0020538 SNOMEDCT_US[38341003]", "attribute": {"sentence_prob": "0.926", "concept_prob": "0.976", "umlsCuiDesc": "Hypertensive disease"}}
# entTo {"begin": 2318, "end": 2324, "cui": null, "attribute": null}
# entFrom {"begin": 2371, "end": 2394, "cui": "C1636672 SNOMEDCT_US[420006002]", "attribute": {"sentence_prob": "0.926", "concept_prob": "1.0", "umlsCuiDesc": "Obliterative coronary artery disease"}}
# entTo {"begin": 2318, "end": 2324, "cui": null, "attribute": null}
# entFrom {"begin": 2371, "end": 2394, "cui": "C1636672 SNOMEDCT_US[420006002]", "attribute": {"sentence_prob": "0.926", "concept_prob": "1.0", "umlsCuiDesc": "Obliterative coronary artery disease"}}
# entTo {"begin": 2371, "end": 2386, "cui": null, "attribute": null}
# entFrom {"begin": 2471, "end": 2477, "cui": "C0260515 SNOMEDCT_US[275937001]", "attribute": {"sentence_prob": "0.571", "concept_prob": "0.998", "umlsCuiDesc": "Family history of cancer"}}
# entTo {"begin": 2468, "end": 2470, "cui": null, "attribute": null}
# entFrom {"begin": 2481, "end": 2495, "cui": null, "attribute": {"sentence_prob": 0.571, "concept_prob": 0.983}}
# entTo {"begin": 2468, "end": 2470, "cui": null, "attribute": null}
# entFrom {"begin": 2897, "end": 2929, "cui": null, "attribute": {"sentence_prob": 0.977, "concept_prob": 1.0}}
# entTo {"begin": 2924, "end": 2929, "cui": null, "attribute": null}
# entFrom {"begin": 2897, "end": 2929, "cui": null, "attribute": {"sentence_prob": 0.977, "concept_prob": 1.0}}
# entTo {"begin": 2891, "end": 2895, "cui": null, "attribute": null}
# entFrom {"begin": 3043, "end": 3061, "cui": "C0019214 SNOMEDCT_US[36760000]", "attribute": {"sentence_prob": "1.0", "concept_prob": "1.0", "umlsCuiDesc": "Hepatosplenomegaly"}}
# entTo {"begin": 3040, "end": 3042, "cui": null, "attribute": null}
# entFrom {"begin": 3079, "end": 3084, "cui": "C0013604 SNOMEDCT_US[267038008, 79654002, 423666004, 20741006]", "attribute": {"sentence_prob": "0.999", "concept_prob": "1.0", "umlsCuiDesc": "Edema"}}
# entTo {"begin": 3076, "end": 3078, "cui": null, "attribute": null}
# entFrom {"begin": 3079, "end": 3084, "cui": "C0013604 SNOMEDCT_US[267038008, 79654002, 423666004, 20741006]", "attribute": {"sentence_prob": "0.999", "concept_prob": "1.0", "umlsCuiDesc": "Edema"}}
# entTo {"begin": 3063, "end": 3074, "cui": null, "attribute": null}
# entFrom {"begin": 2566, "end": 2572, "cui": "C0162723, RxNorm=[58930], Generic=[58930]", "attribute": null}
# entTo {"begin": 2579, "end": 2585, "cui": null, "attribute": null}
# entFrom {"begin": 2587, "end": 2594, "cui": "RxNorm=[324026], Generic=[324026]", "attribute": null}
# entTo {"begin": 2602, "end": 2608, "cui": null, "attribute": null}
# entFrom {"begin": 2610, "end": 2619, "cui": "RxNorm=[966251], Generic=[224920]", "attribute": null}
# entTo {"begin": 2627, "end": 2632, "cui": null, "attribute": null}
# entFrom {"begin": 2610, "end": 2619, "cui": "RxNorm=[966251], Generic=[224920]", "attribute": null}
# entTo {"begin": 2620, "end": 2626, "cui": null, "attribute": null}
# entFrom {"begin": 2634, "end": 2642, "cui": "C0591395, RxNorm=[151651], Generic=[151651]", "attribute": null}
# entTo {"begin": 2648, "end": 2653, "cui": null, "attribute": null}
# entFrom {"begin": 2655, "end": 2665, "cui": "C0032952, RxNorm=[8640], Generic=[8640]", "attribute": null}
# entTo {"begin": 2686, "end": 2695, "cui": null, "attribute": null}
# entFrom {"begin": 2655, "end": 2665, "cui": "C0032952, RxNorm=[8640], Generic=[8640]", "attribute": null}
# entTo {"begin": 2672, "end": 2678, "cui": null, "attribute": null}
# entFrom {"begin": 3106, "end": 3112, "cui": null, "attribute": null}
# entTo {"begin": 3088, "end": 3105, "cui": "C0232139", "attribute": {"sentence_prob": "0.85", "concept_prob": "0.853", "umlsCuiDesc": "Peripheral pulse"}}
# 538371741 538371741.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# 542219766 542219766.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 61, "end": 98, "cui": null, "attribute": {"sentence_prob": 0.499, "concept_prob": 0.926}}
# entTo {"begin": 88, "end": 98, "cui": null, "attribute": null}
# entFrom {"begin": 161, "end": 173, "cui": null, "attribute": {"sentence_prob": 0.39, "concept_prob": 0.769}}
# entTo {"begin": 156, "end": 160, "cui": null, "attribute": null}
# 3282716435 3282716435.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 431, "end": 454, "cui": null, "attribute": {"sentence_prob": 0.599, "concept_prob": 0.995}}
# entTo {"begin": 414, "end": 422, "cui": null, "attribute": null}
# entFrom {"begin": 466, "end": 478, "cui": null, "attribute": {"sentence_prob": 0.599, "concept_prob": 0.962}}
# entTo {"begin": 414, "end": 422, "cui": null, "attribute": null}
# entFrom {"begin": 647, "end": 698, "cui": null, "attribute": {"sentence_prob": 0.509, "concept_prob": 0.513}}
# entTo {"begin": 663, "end": 671, "cui": null, "attribute": null}
# entFrom {"begin": 647, "end": 698, "cui": null, "attribute": {"sentence_prob": 0.509, "concept_prob": 0.513}}
# entTo {"begin": 679, "end": 684, "cui": null, "attribute": null}
# entFrom {"begin": 558, "end": 566, "cui": "C2586989, RxNorm=[830838], Generic=[203494]", "attribute": null}
# entTo {"begin": 582, "end": 589, "cui": null, "attribute": null}
# entFrom {"begin": 558, "end": 566, "cui": "C2586989, RxNorm=[830838], Generic=[203494]", "attribute": null}
# entTo {"begin": 575, "end": 581, "cui": null, "attribute": null}
# 7485884886-7 7485884886-7.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 189, "end": 207, "cui": null, "attribute": {"sentence_prob": 0.683, "concept_prob": 0.979}}
# entTo {"begin": 189, "end": 202, "cui": null, "attribute": null}
# entFrom {"begin": 234, "end": 253, "cui": null, "attribute": {"sentence_prob": 0.683, "concept_prob": 0.925}}
# entTo {"begin": 226, "end": 233, "cui": null, "attribute": null}
# entFrom {"begin": 294, "end": 312, "cui": "C0151699 SNOMEDCT_US[1386000]", "attribute": {"sentence_prob": "0.991", "concept_prob": "0.997", "umlsCuiDesc": "Intracranial Hemorrhages"}}
# entTo {"begin": 294, "end": 306, "cui": null, "attribute": null}
# entFrom {"begin": 365, "end": 383, "cui": null, "attribute": {"sentence_prob": 0.991, "concept_prob": 0.993}}
# entTo {"begin": 365, "end": 378, "cui": null, "attribute": null}
# 5801003571-5 5801003571-5.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 50, "end": 87, "cui": null, "attribute": {"sentence_prob": 0.985, "concept_prob": 0.999}}
# entTo {"begin": 59, "end": 78, "cui": null, "attribute": null}
# entFrom {"begin": 113, "end": 177, "cui": null, "attribute": {"sentence_prob": 0.446, "concept_prob": 0.448}}
# entTo {"begin": 122, "end": 133, "cui": null, "attribute": null}
# entFrom {"begin": 113, "end": 177, "cui": null, "attribute": {"sentence_prob": 0.446, "concept_prob": 0.448}}
# entTo {"begin": 155, "end": 168, "cui": null, "attribute": null}
# entFrom {"begin": 610, "end": 640, "cui": null, "attribute": {"sentence_prob": 0.335, "concept_prob": 0.539}}
# entTo {"begin": 607, "end": 609, "cui": null, "attribute": null}
# entFrom {"begin": 948, "end": 1012, "cui": null, "attribute": {"sentence_prob": 0.446, "concept_prob": 0.448}}
# entTo {"begin": 990, "end": 1003, "cui": null, "attribute": null}
# entFrom {"begin": 948, "end": 1012, "cui": null, "attribute": {"sentence_prob": 0.446, "concept_prob": 0.448}}
# entTo {"begin": 957, "end": 968, "cui": null, "attribute": null}
# entFrom {"begin": 1171, "end": 1212, "cui": null, "attribute": {"sentence_prob": 0.683, "concept_prob": 0.712}}
# entTo {"begin": 1160, "end": 1169, "cui": null, "attribute": null}
# entFrom {"begin": 1171, "end": 1212, "cui": null, "attribute": {"sentence_prob": 0.683, "concept_prob": 0.712}}
# entTo {"begin": 1171, "end": 1182, "cui": null, "attribute": null}
# entFrom {"begin": 1702, "end": 1718, "cui": null, "attribute": {"sentence_prob": 0.851, "concept_prob": 0.997}}
# entTo {"begin": 1699, "end": 1701, "cui": null, "attribute": null}
# entFrom {"begin": 1916, "end": 1941, "cui": null, "attribute": {"sentence_prob": 0.836, "concept_prob": 0.906}}
# entTo {"begin": 1918, "end": 1922, "cui": null, "attribute": null}
# entFrom {"begin": 1984, "end": 1994, "cui": "C0234234 SNOMEDCT_US[300820003]", "attribute": {"sentence_prob": "0.927", "concept_prob": "0.997", "umlsCuiDesc": "Tender"}}
# entTo {"begin": 1981, "end": 1983, "cui": null, "attribute": null}
# entFrom {"begin": 2048, "end": 2073, "cui": null, "attribute": {"sentence_prob": 0.611, "concept_prob": 0.808}}
# entTo {"begin": 2045, "end": 2047, "cui": null, "attribute": null}
# entFrom {"begin": 2048, "end": 2073, "cui": null, "attribute": {"sentence_prob": 0.611, "concept_prob": 0.808}}
# entTo {"begin": 2062, "end": 2073, "cui": null, "attribute": null}
# entFrom {"begin": 2304, "end": 2308, "cui": "C0242936 SNOMEDCT_US[702897005]", "attribute": {"sentence_prob": "0.462", "concept_prob": "0.979", "umlsCuiDesc": "Pain Clinics"}}
# entTo {"begin": 2301, "end": 2303, "cui": null, "attribute": null}
# entFrom {"begin": 2408, "end": 2430, "cui": null, "attribute": {"sentence_prob": 0.565, "concept_prob": 0.624}}
# entTo {"begin": 2414, "end": 2423, "cui": null, "attribute": null}
# 527602912 527602912.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 439, "end": 462, "cui": null, "attribute": {"sentence_prob": 0.422, "concept_prob": 0.952}}
# entTo {"begin": 428, "end": 438, "cui": null, "attribute": null}
# entFrom {"begin": 705, "end": 730, "cui": null, "attribute": {"sentence_prob": 0.381, "concept_prob": 0.388}}
# entTo {"begin": 652, "end": 654, "cui": null, "attribute": null}
# entFrom {"begin": 862, "end": 870, "cui": "C0086132 SNOMEDCT_US[394924000]", "attribute": {"sentence_prob": "0.803", "concept_prob": "0.994", "umlsCuiDesc": "Depressive Symptoms"}}
# entTo {"begin": 859, "end": 861, "cui": null, "attribute": null}
# entFrom {"begin": 862, "end": 870, "cui": "C0086132 SNOMEDCT_US[394924000]", "attribute": {"sentence_prob": "0.803", "concept_prob": "0.994", "umlsCuiDesc": "Depressive Symptoms"}}
# entTo {"begin": 953, "end": 968, "cui": null, "attribute": null}
# entFrom {"begin": 1026, "end": 1064, "cui": null, "attribute": {"sentence_prob": 0.659, "concept_prob": 0.997}}
# entTo {"begin": 971, "end": 973, "cui": null, "attribute": null}
# entFrom {"begin": 1308, "end": 1324, "cui": "C2895043 SNOMEDCT_US[316991000119100]", "attribute": {"sentence_prob": "0.95", "concept_prob": "0.951", "umlsCuiDesc": "Pain of right wrist"}}
# entTo {"begin": 1308, "end": 1319, "cui": null, "attribute": null}
# entFrom {"begin": 1383, "end": 1399, "cui": "C2895043 SNOMEDCT_US[316991000119100]", "attribute": {"sentence_prob": "0.95", "concept_prob": "0.951", "umlsCuiDesc": "Pain of right wrist"}}
# entTo {"begin": 1383, "end": 1394, "cui": null, "attribute": null}
# entFrom {"begin": 1562, "end": 1578, "cui": "C2895043 SNOMEDCT_US[316991000119100]", "attribute": {"sentence_prob": "0.899", "concept_prob": "0.972", "umlsCuiDesc": "Pain of right wrist"}}
# entTo {"begin": 1562, "end": 1573, "cui": null, "attribute": null}
# entFrom {"begin": 1647, "end": 1681, "cui": null, "attribute": {"sentence_prob": 0.684, "concept_prob": 0.998}}
# entTo {"begin": 1640, "end": 1646, "cui": null, "attribute": null}
# entFrom {"begin": 2320, "end": 2367, "cui": null, "attribute": {"sentence_prob": 0.279, "concept_prob": 0.953}}
# entTo {"begin": 2349, "end": 2354, "cui": null, "attribute": null}
# entFrom {"begin": 2791, "end": 2817, "cui": null, "attribute": {"sentence_prob": 0.973, "concept_prob": 0.99}}
# entTo {"begin": 2788, "end": 2790, "cui": null, "attribute": null}
# entFrom {"begin": 2568, "end": 2575, "cui": "RxNorm=[10072], Generic=[10072]", "attribute": null}
# entTo {"begin": 2547, "end": 2554, "cui": null, "attribute": null}
# entFrom {"begin": 2249, "end": 2255, "cui": null, "attribute": null}
# entTo {"begin": 2202, "end": 2209, "cui": "C0040405", "attribute": {"sentence_prob": "0.747", "concept_prob": "0.995", "umlsCuiDesc": "X-Ray Computed Tomography"}}
# 531921262 531921262.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 156, "end": 168, "cui": "C0178415 SNOMEDCT_US[396152005]", "attribute": {"sentence_prob": "0.639", "concept_prob": "0.821", "umlsCuiDesc": "Raised prostate specific antigen"}}
# entTo {"begin": 156, "end": 164, "cui": null, "attribute": null}
# entFrom {"begin": 219, "end": 242, "cui": null, "attribute": {"sentence_prob": 0.352, "concept_prob": 0.994}}
# entTo {"begin": 224, "end": 231, "cui": null, "attribute": null}
# entFrom {"begin": 436, "end": 448, "cui": "C0178415 SNOMEDCT_US[396152005]", "attribute": {"sentence_prob": "0.285", "concept_prob": "0.999", "umlsCuiDesc": "Raised prostate specific antigen"}}
# entTo {"begin": 436, "end": 444, "cui": null, "attribute": null}
# entFrom {"begin": 497, "end": 520, "cui": "C1636672 SNOMEDCT_US[420006002]", "attribute": {"sentence_prob": "0.737", "concept_prob": "0.983", "umlsCuiDesc": "Obliterative coronary artery disease"}}
# entTo {"begin": 497, "end": 512, "cui": null, "attribute": null}
# entFrom {"begin": 573, "end": 596, "cui": "C0026106 SNOMEDCT_US[86765009]", "attribute": {"sentence_prob": "0.966", "concept_prob": "0.968", "umlsCuiDesc": "Mild Mental Retardation"}}
# entTo {"begin": 573, "end": 577, "cui": null, "attribute": null}
# entFrom {"begin": 600, "end": 632, "cui": null, "attribute": {"sentence_prob": 0.968, "concept_prob": 0.971}}
# entTo {"begin": 613, "end": 626, "cui": null, "attribute": null}
# entFrom {"begin": 296, "end": 299, "cui": null, "attribute": null}
# entTo {"begin": 279, "end": 291, "cui": "C0941108", "attribute": {"sentence_prob": "0.838", "concept_prob": "0.839", "umlsCuiDesc": "food in the stomach"}}
# 3287783778 3287783778.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 146, "end": 162, "cui": null, "attribute": {"sentence_prob": 0.727, "concept_prob": 0.943}}
# entTo {"begin": 146, "end": 152, "cui": null, "attribute": null}
# entFrom {"begin": 206, "end": 238, "cui": null, "attribute": {"sentence_prob": 0.749, "concept_prob": 0.971}}
# entTo {"begin": 229, "end": 238, "cui": null, "attribute": null}
# entFrom {"begin": 300, "end": 308, "cui": null, "attribute": {"sentence_prob": 0.363, "concept_prob": 0.84}}
# entTo {"begin": 293, "end": 299, "cui": null, "attribute": null}
# entFrom {"begin": 438, "end": 451, "cui": null, "attribute": {"sentence_prob": 0.935, "concept_prob": 0.969}}
# entTo {"begin": 452, "end": 460, "cui": null, "attribute": null}
# entFrom {"begin": 491, "end": 500, "cui": "C0018681 SNOMEDCT_US[25064002]", "attribute": {"sentence_prob": "0.978", "concept_prob": "0.979", "umlsCuiDesc": "Headache"}}
# entTo {"begin": 488, "end": 490, "cui": null, "attribute": null}
# entFrom {"begin": 890, "end": 911, "cui": null, "attribute": {"sentence_prob": 0.925, "concept_prob": 0.996}}
# entTo {"begin": 890, "end": 902, "cui": null, "attribute": null}
# entFrom {"begin": 1055, "end": 1083, "cui": null, "attribute": {"sentence_prob": 0.869, "concept_prob": 0.952}}
# entTo {"begin": 1052, "end": 1054, "cui": null, "attribute": null}
# entFrom {"begin": 1378, "end": 1390, "cui": "C0030252 SNOMEDCT_US[80313002]", "attribute": {"sentence_prob": "0.846", "concept_prob": "1.0", "umlsCuiDesc": "Palpitations"}}
# entTo {"begin": 1371, "end": 1377, "cui": null, "attribute": null}
# entFrom {"begin": 1392, "end": 1411, "cui": "C0013404 SNOMEDCT_US[267036007, 230145002]", "attribute": {"sentence_prob": "0.846", "concept_prob": "0.996", "umlsCuiDesc": "Dyspnea"}}
# entTo {"begin": 1371, "end": 1377, "cui": null, "attribute": null}
# entFrom {"begin": 1392, "end": 1411, "cui": "C0013404 SNOMEDCT_US[267036007, 230145002]", "attribute": {"sentence_prob": "0.846", "concept_prob": "0.996", "umlsCuiDesc": "Dyspnea"}}
# entTo {"begin": 1405, "end": 1411, "cui": null, "attribute": null}
# entFrom {"begin": 1413, "end": 1434, "cui": "C0278008 SNOMEDCT_US[88111009]", "attribute": {"sentence_prob": "0.846", "concept_prob": "0.996", "umlsCuiDesc": "Altered bowel function"}}
# entTo {"begin": 1371, "end": 1377, "cui": null, "attribute": null}
# entFrom {"begin": 1413, "end": 1434, "cui": "C0278008 SNOMEDCT_US[88111009]", "attribute": {"sentence_prob": "0.846", "concept_prob": "0.996", "umlsCuiDesc": "Altered bowel function"}}
# entTo {"begin": 1423, "end": 1428, "cui": null, "attribute": null}
# entFrom {"begin": 1438, "end": 1452, "cui": "C0558772 SNOMEDCT_US[274639009]", "attribute": {"sentence_prob": "0.846", "concept_prob": "0.973", "umlsCuiDesc": "Death occurring less than 24 hours from onset of symptoms, not otherwise expected"}}
# entTo {"begin": 1371, "end": 1377, "cui": null, "attribute": null}
# entFrom {"begin": 1464, "end": 1499, "cui": null, "attribute": {"sentence_prob": 0.846, "concept_prob": 0.998}}
# entTo {"begin": 1371, "end": 1377, "cui": null, "attribute": null}
# entFrom {"begin": 1464, "end": 1499, "cui": null, "attribute": {"sentence_prob": 0.846, "concept_prob": 0.998}}
# entTo {"begin": 1456, "end": 1463, "cui": null, "attribute": null}
# entFrom {"begin": 1464, "end": 1499, "cui": null, "attribute": {"sentence_prob": 0.846, "concept_prob": 0.998}}
# entTo {"begin": 1492, "end": 1499, "cui": null, "attribute": null}
# entFrom {"begin": 1464, "end": 1499, "cui": null, "attribute": {"sentence_prob": 0.846, "concept_prob": 0.998}}
# entTo {"begin": 1471, "end": 1478, "cui": null, "attribute": null}
# entFrom {"begin": 1640, "end": 1660, "cui": null, "attribute": {"sentence_prob": 0.966, "concept_prob": 0.998}}
# entTo {"begin": 1637, "end": 1639, "cui": null, "attribute": null}
# entFrom {"begin": 1640, "end": 1660, "cui": null, "attribute": {"sentence_prob": 0.966, "concept_prob": 0.998}}
# entTo {"begin": 1665, "end": 1671, "cui": null, "attribute": null}
# entFrom {"begin": 1672, "end": 1680, "cui": "C0013491 SNOMEDCT_US[77643000, 302227002]", "attribute": {"sentence_prob": "0.966", "concept_prob": "0.998", "umlsCuiDesc": "Ecchymosis"}}
# entTo {"begin": 1665, "end": 1671, "cui": null, "attribute": null}
# entFrom {"begin": 1684, "end": 1696, "cui": "C0421292 SNOMEDCT_US[170859004]", "attribute": {"sentence_prob": "0.966", "concept_prob": "0.977", "umlsCuiDesc": "Skin symptom change"}}
# entTo {"begin": 1665, "end": 1671, "cui": null, "attribute": null}
# entFrom {"begin": 1684, "end": 1696, "cui": "C0421292 SNOMEDCT_US[170859004]", "attribute": {"sentence_prob": "0.966", "concept_prob": "0.977", "umlsCuiDesc": "Skin symptom change"}}
# entTo {"begin": 1684, "end": 1688, "cui": null, "attribute": null}
# entFrom {"begin": 1724, "end": 1743, "cui": "C0403710 SNOMEDCT_US[236703003]", "attribute": {"sentence_prob": "0.847", "concept_prob": "0.989", "umlsCuiDesc": "Recurrent infective cystitis"}}
# entTo {"begin": 1708, "end": 1710, "cui": null, "attribute": null}
# entFrom {"begin": 1833, "end": 1847, "cui": "C4032605 SNOMEDCT_US[713460009]", "attribute": {"sentence_prob": "0.977", "concept_prob": "0.998", "umlsCuiDesc": "Denial about illness severity"}}
# entTo {"begin": 1833, "end": 1839, "cui": null, "attribute": null}
# entFrom {"begin": 2011, "end": 2017, "cui": "C0038435 SNOMEDCT_US[73595000, 262188008]", "attribute": {"sentence_prob": "0.642", "concept_prob": "0.648", "umlsCuiDesc": "Stress"}}
# entTo {"begin": 2018, "end": 2027, "cui": null, "attribute": null}
# entFrom {"begin": 2603, "end": 2638, "cui": null, "attribute": {"sentence_prob": 0.563, "concept_prob": 0.695}}
# entTo {"begin": 2580, "end": 2602, "cui": null, "attribute": null}
# entFrom {"begin": 2603, "end": 2638, "cui": null, "attribute": {"sentence_prob": 0.563, "concept_prob": 0.695}}
# entTo {"begin": 2621, "end": 2630, "cui": null, "attribute": null}
# entFrom {"begin": 2802, "end": 2826, "cui": null, "attribute": {"sentence_prob": 0.824, "concept_prob": 0.976}}
# entTo {"begin": 2811, "end": 2820, "cui": null, "attribute": null}
# entFrom {"begin": 3644, "end": 3674, "cui": null, "attribute": {"sentence_prob": 0.661, "concept_prob": 0.932}}
# entTo {"begin": 3646, "end": 3654, "cui": null, "attribute": null}
# entFrom {"begin": 4297, "end": 4311, "cui": "C0020476 SNOMEDCT_US[3744001]", "attribute": {"sentence_prob": "0.758", "concept_prob": "0.76", "umlsCuiDesc": "Hyperlipoproteinemias"}}
# entTo {"begin": 4290, "end": 4296, "cui": null, "attribute": null}
# entFrom {"begin": 5079, "end": 5099, "cui": null, "attribute": {"sentence_prob": 0.923, "concept_prob": 0.941}}
# entTo {"begin": 5072, "end": 5078, "cui": null, "attribute": null}
# entFrom {"begin": 5103, "end": 5119, "cui": null, "attribute": {"sentence_prob": 0.923, "concept_prob": 0.992}}
# entTo {"begin": 5072, "end": 5078, "cui": null, "attribute": null}
# entFrom {"begin": 5142, "end": 5154, "cui": "C0030252 SNOMEDCT_US[80313002]", "attribute": {"sentence_prob": "0.997", "concept_prob": "1.0", "umlsCuiDesc": "Palpitations"}}
# entTo {"begin": 5139, "end": 5141, "cui": null, "attribute": null}
# entFrom {"begin": 5142, "end": 5154, "cui": "C0030252 SNOMEDCT_US[80313002]", "attribute": {"sentence_prob": "0.997", "concept_prob": "1.0", "umlsCuiDesc": "Palpitations"}}
# entTo {"begin": 5135, "end": 5137, "cui": null, "attribute": null}
# entFrom {"begin": 5158, "end": 5168, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "0.997", "concept_prob": "0.998", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 5139, "end": 5141, "cui": null, "attribute": null}
# entFrom {"begin": 5158, "end": 5168, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "0.997", "concept_prob": "0.998", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 5158, "end": 5163, "cui": null, "attribute": null}
# entFrom {"begin": 5158, "end": 5168, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "0.997", "concept_prob": "0.998", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 5135, "end": 5137, "cui": null, "attribute": null}
# entFrom {"begin": 818, "end": 823, "cui": "C2684543, RxNorm=[849523], Generic=[203658]", "attribute": null}
# entTo {"begin": 859, "end": 867, "cui": null, "attribute": null}
# entFrom {"begin": 818, "end": 823, "cui": "C2684543, RxNorm=[849523], Generic=[203658]", "attribute": null}
# entTo {"begin": 852, "end": 857, "cui": null, "attribute": null}
# entFrom {"begin": 818, "end": 823, "cui": "C2684543, RxNorm=[849523], Generic=[203658]", "attribute": null}
# entTo {"begin": 845, "end": 851, "cui": null, "attribute": null}
# entFrom {"begin": 1203, "end": 1212, "cui": "C2747446, RxNorm=[966342], Generic=[224920]", "attribute": null}
# entTo {"begin": 1222, "end": 1227, "cui": null, "attribute": null}
# entFrom {"begin": 1203, "end": 1212, "cui": "C2747446, RxNorm=[966342], Generic=[224920]", "attribute": null}
# entTo {"begin": 1213, "end": 1221, "cui": null, "attribute": null}
# entFrom {"begin": 1882, "end": 1889, "cui": "RxNorm=[10072], Generic=[10072]", "attribute": null}
# entTo {"begin": 1870, "end": 1881, "cui": null, "attribute": null}
# entFrom {"begin": 1946, "end": 1954, "cui": "RxNorm=[10072], Generic=[10072]", "attribute": null}
# entTo {"begin": 2018, "end": 2027, "cui": null, "attribute": null}
# entFrom {"begin": 2048, "end": 2060, "cui": "C1125815, RxNorm=[330253], Generic=[10379]", "attribute": null}
# entTo {"begin": 2097, "end": 2099, "cui": null, "attribute": null}
# entFrom {"begin": 2048, "end": 2060, "cui": "C1125815, RxNorm=[330253], Generic=[10379]", "attribute": null}
# entTo {"begin": 2088, "end": 2094, "cui": null, "attribute": null}
# entFrom {"begin": 3728, "end": 3737, "cui": "C2747439, RxNorm=[966335], Generic=[224920]", "attribute": null}
# entTo {"begin": 3831, "end": 3840, "cui": null, "attribute": null}
# entFrom {"begin": 3728, "end": 3737, "cui": "C2747439, RxNorm=[966335], Generic=[224920]", "attribute": null}
# entTo {"begin": 3760, "end": 3765, "cui": null, "attribute": null}
# entFrom {"begin": 3728, "end": 3737, "cui": "C2747439, RxNorm=[966335], Generic=[224920]", "attribute": null}
# entTo {"begin": 3751, "end": 3759, "cui": null, "attribute": null}
# entFrom {"begin": 4679, "end": 4688, "cui": "C2747439, RxNorm=[966335], Generic=[224920]", "attribute": null}
# entTo {"begin": 4698, "end": 4703, "cui": null, "attribute": null}
# entFrom {"begin": 4679, "end": 4688, "cui": "C2747439, RxNorm=[966335], Generic=[224920]", "attribute": null}
# entTo {"begin": 4689, "end": 4697, "cui": null, "attribute": null}
# entFrom {"begin": 2274, "end": 2277, "cui": null, "attribute": null}
# entTo {"begin": 2262, "end": 2265, "cui": "C0138741", "attribute": {"sentence_prob": "0.978", "concept_prob": "0.982", "umlsCuiDesc": "Prostate-Specific Antigen"}}
# entFrom {"begin": 3256, "end": 3259, "cui": null, "attribute": null}
# entTo {"begin": 3234, "end": 3237, "cui": "C0138741", "attribute": {"sentence_prob": "0.933", "concept_prob": "0.944", "umlsCuiDesc": "Prostate-Specific Antigen"}}
# entFrom {"begin": 4556, "end": 4559, "cui": null, "attribute": null}
# entTo {"begin": 4549, "end": 4555, "cui": "C0037473", "attribute": {"sentence_prob": "0.994", "concept_prob": "0.994", "umlsCuiDesc": "Sodium"}}
# entFrom {"begin": 4586, "end": 4590, "cui": null, "attribute": null}
# entTo {"begin": 4562, "end": 4572, "cui": "C0019046", "attribute": {"sentence_prob": "0.994", "concept_prob": "0.995", "umlsCuiDesc": "Hemoglobin"}}
# 562073697 562073697.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 31, "end": 54, "cui": "C1636672 SNOMEDCT_US[420006002]", "attribute": {"sentence_prob": "0.992", "concept_prob": "0.992", "umlsCuiDesc": "Obliterative coronary artery disease"}}
# entTo {"begin": 31, "end": 46, "cui": null, "attribute": null}
# entFrom {"begin": 82, "end": 106, "cui": "C0264722 SNOMEDCT_US[88805009]", "attribute": {"sentence_prob": "0.999", "concept_prob": "1.0", "umlsCuiDesc": "Chronic congestive heart failure"}}
# entTo {"begin": 93, "end": 98, "cui": null, "attribute": null}
# entFrom {"begin": 128, "end": 155, "cui": "C0403447 SNOMEDCT_US[709044004]", "attribute": {"sentence_prob": "0.843", "concept_prob": "0.846", "umlsCuiDesc": "Chronic Kidney Insufficiency"}}
# entTo {"begin": 136, "end": 141, "cui": null, "attribute": null}
# entFrom {"begin": 293, "end": 316, "cui": "C1636672 SNOMEDCT_US[420006002]", "attribute": {"sentence_prob": "0.992", "concept_prob": "0.992", "umlsCuiDesc": "Obliterative coronary artery disease"}}
# entTo {"begin": 293, "end": 308, "cui": null, "attribute": null}
# entFrom {"begin": 326, "end": 350, "cui": "C0264722 SNOMEDCT_US[88805009]", "attribute": {"sentence_prob": "0.999", "concept_prob": "1.0", "umlsCuiDesc": "Chronic congestive heart failure"}}
# entTo {"begin": 337, "end": 342, "cui": null, "attribute": null}
# entFrom {"begin": 354, "end": 381, "cui": "C0403447 SNOMEDCT_US[709044004]", "attribute": {"sentence_prob": "0.843", "concept_prob": "0.846", "umlsCuiDesc": "Chronic Kidney Insufficiency"}}
# entTo {"begin": 362, "end": 367, "cui": null, "attribute": null}
# entFrom {"begin": 568, "end": 598, "cui": "C3873497 SNOMEDCT_US[707224005]", "attribute": {"sentence_prob": "0.925", "concept_prob": "0.991", "umlsCuiDesc": "Severe acute respiratory infection"}}
# entTo {"begin": 576, "end": 587, "cui": null, "attribute": null}
# entFrom {"begin": 713, "end": 725, "cui": null, "attribute": {"sentence_prob": 0.749, "concept_prob": 0.837}}
# entTo {"begin": 706, "end": 712, "cui": null, "attribute": null}
# entFrom {"begin": 799, "end": 823, "cui": "C0264722 SNOMEDCT_US[88805009]", "attribute": {"sentence_prob": "0.991", "concept_prob": "0.992", "umlsCuiDesc": "Chronic congestive heart failure"}}
# entTo {"begin": 810, "end": 815, "cui": null, "attribute": null}
# entFrom {"begin": 880, "end": 903, "cui": "C1636672 SNOMEDCT_US[420006002]", "attribute": {"sentence_prob": "0.984", "concept_prob": "0.985", "umlsCuiDesc": "Obliterative coronary artery disease"}}
# entTo {"begin": 880, "end": 895, "cui": null, "attribute": null}
# entFrom {"begin": 965, "end": 996, "cui": null, "attribute": {"sentence_prob": 0.753, "concept_prob": 0.806}}
# entTo {"begin": 1031, "end": 1034, "cui": null, "attribute": null}
# entFrom {"begin": 965, "end": 996, "cui": null, "attribute": {"sentence_prob": 0.753, "concept_prob": 0.806}}
# entTo {"begin": 1035, "end": 1042, "cui": null, "attribute": null}
# entFrom {"begin": 965, "end": 996, "cui": null, "attribute": {"sentence_prob": 0.753, "concept_prob": 0.806}}
# entTo {"begin": 981, "end": 986, "cui": null, "attribute": null}
# entFrom {"begin": 1109, "end": 1136, "cui": "C0403447 SNOMEDCT_US[709044004]", "attribute": {"sentence_prob": "1.0", "concept_prob": "1.0", "umlsCuiDesc": "Chronic Kidney Insufficiency"}}
# entTo {"begin": 1117, "end": 1122, "cui": null, "attribute": null}
# entFrom {"begin": 1212, "end": 1236, "cui": "C0264722 SNOMEDCT_US[88805009]", "attribute": {"sentence_prob": "1.0", "concept_prob": "1.0", "umlsCuiDesc": "Chronic congestive heart failure"}}
# entTo {"begin": 1223, "end": 1228, "cui": null, "attribute": null}
# entFrom {"begin": 1237, "end": 1260, "cui": "C1636672 SNOMEDCT_US[420006002]", "attribute": {"sentence_prob": "0.999", "concept_prob": "0.999", "umlsCuiDesc": "Obliterative coronary artery disease"}}
# entTo {"begin": 1237, "end": 1252, "cui": null, "attribute": null}
# entFrom {"begin": 1734, "end": 1744, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "0.928", "concept_prob": "0.994", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 1730, "end": 1733, "cui": null, "attribute": null}
# entFrom {"begin": 1734, "end": 1744, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "0.928", "concept_prob": "0.994", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 1734, "end": 1739, "cui": null, "attribute": null}
# entFrom {"begin": 1895, "end": 1904, "cui": "C0018681 SNOMEDCT_US[25064002]", "attribute": {"sentence_prob": "0.961", "concept_prob": "0.987", "umlsCuiDesc": "Headache"}}
# entTo {"begin": 1892, "end": 1894, "cui": null, "attribute": null}
# entFrom {"begin": 1912, "end": 1923, "cui": "C0042798 SNOMEDCT_US[246635007]", "attribute": {"sentence_prob": "0.977", "concept_prob": "0.984", "umlsCuiDesc": "Low Vision"}}
# entTo {"begin": 1905, "end": 1909, "cui": null, "attribute": null}
# entFrom {"begin": 1937, "end": 1957, "cui": "C0024437 SNOMEDCT_US[422338006]", "attribute": {"sentence_prob": "0.977", "concept_prob": "1.0", "umlsCuiDesc": "Macular degeneration"}}
# entTo {"begin": 1937, "end": 1944, "cui": null, "attribute": null}
# entFrom {"begin": 2028, "end": 2038, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "0.928", "concept_prob": "0.943", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 2028, "end": 2033, "cui": null, "attribute": null}
# entFrom {"begin": 2028, "end": 2038, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "0.928", "concept_prob": "0.943", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 2007, "end": 2009, "cui": null, "attribute": null}
# entFrom {"begin": 2053, "end": 2079, "cui": null, "attribute": {"sentence_prob": 0.705, "concept_prob": 0.916}}
# entTo {"begin": 2060, "end": 2068, "cui": null, "attribute": null}
# entFrom {"begin": 2053, "end": 2079, "cui": null, "attribute": {"sentence_prob": 0.705, "concept_prob": 0.916}}
# entTo {"begin": 2039, "end": 2050, "cui": null, "attribute": null}
# entFrom {"begin": 2118, "end": 2123, "cui": "C0687152 SNOMEDCT_US[289114008]", "attribute": {"sentence_prob": "0.705", "concept_prob": "0.988", "umlsCuiDesc": "Does cough"}}
# entTo {"begin": 2115, "end": 2117, "cui": null, "attribute": null}
# entFrom {"begin": 2132, "end": 2151, "cui": null, "attribute": {"sentence_prob": 0.947, "concept_prob": 0.996}}
# entTo {"begin": 2129, "end": 2131, "cui": null, "attribute": null}
# entFrom {"begin": 2132, "end": 2151, "cui": null, "attribute": {"sentence_prob": 0.947, "concept_prob": 0.996}}
# entTo {"begin": 2124, "end": 2126, "cui": null, "attribute": null}
# entFrom {"begin": 2132, "end": 2151, "cui": null, "attribute": {"sentence_prob": 0.947, "concept_prob": 0.996}}
# entTo {"begin": 2146, "end": 2151, "cui": null, "attribute": null}
# entFrom {"begin": 2184, "end": 2200, "cui": "C0426359 SNOMEDCT_US[249274008]", "attribute": {"sentence_prob": "0.732", "concept_prob": "1.0", "umlsCuiDesc": "Urinary symptoms"}}
# entTo {"begin": 2181, "end": 2183, "cui": null, "attribute": null}
# entFrom {"begin": 2184, "end": 2200, "cui": "C0426359 SNOMEDCT_US[249274008]", "attribute": {"sentence_prob": "0.732", "concept_prob": "1.0", "umlsCuiDesc": "Urinary symptoms"}}
# entTo {"begin": 2184, "end": 2191, "cui": null, "attribute": null}
# entFrom {"begin": 2211, "end": 2239, "cui": null, "attribute": {"sentence_prob": 0.732, "concept_prob": 0.997}}
# entTo {"begin": 2222, "end": 2229, "cui": null, "attribute": null}
# entFrom {"begin": 2295, "end": 2303, "cui": "C0033213 SNOMEDCT_US[55607006]", "attribute": {"sentence_prob": "0.938", "concept_prob": "0.945", "umlsCuiDesc": "Problem"}}
# entTo {"begin": 2292, "end": 2294, "cui": null, "attribute": null}
# entFrom {"begin": 2295, "end": 2303, "cui": "C0033213 SNOMEDCT_US[55607006]", "attribute": {"sentence_prob": "0.938", "concept_prob": "0.945", "umlsCuiDesc": "Problem"}}
# entTo {"begin": 2285, "end": 2289, "cui": null, "attribute": null}
# entFrom {"begin": 2315, "end": 2325, "cui": "C1299586 SNOMEDCT_US[371157007]", "attribute": {"sentence_prob": "0.827", "concept_prob": "0.889", "umlsCuiDesc": "Has difficulty doing (qualifier value)"}}
# entTo {"begin": 2312, "end": 2314, "cui": null, "attribute": null}
# entFrom {"begin": 615, "end": 620, "cui": "C0699992, RxNorm=[202991], Generic=[202991]", "attribute": null}
# entTo {"begin": 658, "end": 665, "cui": null, "attribute": null}
# entFrom {"begin": 1467, "end": 1472, "cui": "C0699992, RxNorm=[202991], Generic=[202991]", "attribute": null}
# entTo {"begin": 1480, "end": 1482, "cui": null, "attribute": null}
# entFrom {"begin": 1483, "end": 1490, "cui": "C0985542, RxNorm=[315819], Generic=[3407]", "attribute": null}
# entTo {"begin": 1512, "end": 1514, "cui": null, "attribute": null}
# entFrom {"begin": 1483, "end": 1490, "cui": "C0985542, RxNorm=[315819], Generic=[3407]", "attribute": null}
# entTo {"begin": 1501, "end": 1511, "cui": null, "attribute": null}
# entFrom {"begin": 1483, "end": 1490, "cui": "C0985542, RxNorm=[315819], Generic=[3407]", "attribute": null}
# entTo {"begin": 1492, "end": 1500, "cui": null, "attribute": null}
# entFrom {"begin": 1515, "end": 1522, "cui": "C0004057, RxNorm=[1191], Generic=[1191]", "attribute": null}
# entTo {"begin": 1530, "end": 1532, "cui": null, "attribute": null}
# entFrom {"begin": 1562, "end": 1569, "cui": "RxNorm=[151187], Generic=[151187]", "attribute": null}
# entTo {"begin": 1576, "end": 1579, "cui": null, "attribute": null}
# entFrom {"begin": 1580, "end": 1588, "cui": "C0591130, RxNorm=[151390], Generic=[151390]", "attribute": null}
# entTo {"begin": 1603, "end": 1606, "cui": null, "attribute": null}
# entFrom {"begin": 1607, "end": 1623, "cui": "RxNorm=[1133], Generic=[1133]", "attribute": null}
# entTo {"begin": 1660, "end": 1663, "cui": null, "attribute": null}
# entFrom {"begin": 1664, "end": 1677, "cui": "C0723125, RxNorm=[996492], Generic=[996492]", "attribute": null}
# entTo {"begin": 1695, "end": 1698, "cui": null, "attribute": null}
# entFrom {"begin": 1664, "end": 1677, "cui": "C0723125, RxNorm=[996492], Generic=[996492]", "attribute": null}
# entTo {"begin": 1688, "end": 1691, "cui": null, "attribute": null}
# entFrom {"begin": 1699, "end": 1708, "cui": "RxNorm=[1297120], Generic=[202525]", "attribute": null}
# entTo {"begin": 1730, "end": 1733, "cui": null, "attribute": null}
# entFrom {"begin": 1699, "end": 1708, "cui": "RxNorm=[1297120], Generic=[202525]", "attribute": null}
# entTo {"begin": 1719, "end": 1729, "cui": null, "attribute": null}
# entFrom {"begin": 1745, "end": 1754, "cui": "C0040805, RxNorm=[10737], Generic=[10737]", "attribute": null}
# entTo {"begin": 1767, "end": 1770, "cui": null, "attribute": null}
# entFrom {"begin": 1771, "end": 1783, "cui": "C0282386, RxNorm=[82122], Generic=[82122]", "attribute": null}
# entTo {"begin": 1803, "end": 1810, "cui": null, "attribute": null}
# entFrom {"begin": 1771, "end": 1783, "cui": "C0282386, RxNorm=[82122], Generic=[82122]", "attribute": null}
# entTo {"begin": 1792, "end": 1794, "cui": null, "attribute": null}
# 6335585185-6 6335585185-6.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# 559605027-9 559605027-9.txt.xmi
# ...
# entTo {"begin": 4747, "end": 4753, "cui": null, "attribute": null}
# entFrom {"begin": 4761, "end": 4770, "cui": "RxNorm=[224920], Generic=[224920]", "attribute": null}
# entTo {"begin": 4780, "end": 4784, "cui": null, "attribute": null}
# entFrom {"begin": 4761, "end": 4770, "cui": "RxNorm=[224920], Generic=[224920]", "attribute": null}
# entTo {"begin": 4772, "end": 4779, "cui": null, "attribute": null}
# entFrom {"begin": 4785, "end": 4792, "cui": "RxNorm=[114265], Generic=[114265]", "attribute": null}
# entTo {"begin": 4799, "end": 4803, "cui": null, "attribute": null}
# entFrom {"begin": 4804, "end": 4812, "cui": "C0004147, RxNorm=[1202], Generic=[1202]", "attribute": null}
# entTo {"begin": 4820, "end": 4824, "cui": null, "attribute": null}
# entFrom {"begin": 4825, "end": 4835, "cui": "RxNorm=[85783], Generic=[85783]", "attribute": null}
# entTo {"begin": 4846, "end": 4850, "cui": null, "attribute": null}
# entFrom {"begin": 77, "end": 81, "cui": null, "attribute": null}
# entTo {"begin": 61, "end": 73, "cui": "C0019016", "attribute": {"sentence_prob": "0.868", "concept_prob": "0.991", "umlsCuiDesc": "Hemoglobin A"}}
# entFrom {"begin": 101, "end": 105, "cui": null, "attribute": null}
# entTo {"begin": 86, "end": 96, "cui": "C0023516", "attribute": {"sentence_prob": "0.868", "concept_prob": "0.979", "umlsCuiDesc": "Leukocytes"}}
# entFrom {"begin": 173, "end": 179, "cui": null, "attribute": null}
# entTo {"begin": 159, "end": 168, "cui": "C0005821", "attribute": {"sentence_prob": "0.773", "concept_prob": "0.995", "umlsCuiDesc": "Blood Platelets"}}
# entFrom {"begin": 221, "end": 223, "cui": null, "attribute": null}
# entTo {"begin": 159, "end": 168, "cui": "C0005821", "attribute": {"sentence_prob": "0.773", "concept_prob": "0.995", "umlsCuiDesc": "Blood Platelets"}}
# entFrom {"begin": 287, "end": 290, "cui": null, "attribute": null}
# entTo {"begin": 262, "end": 269, "cui": "C0017725", "attribute": {"sentence_prob": "0.95", "concept_prob": "0.986", "umlsCuiDesc": "Glucose"}}
# 525344993 525344993.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 45, "end": 54, "cui": "C0851162 SNOMEDCT_US[312154004]", "attribute": {"sentence_prob": "0.346", "concept_prob": "0.689", "umlsCuiDesc": "Infections of musculoskeletal system"}}
# entTo {"begin": 42, "end": 44, "cui": null, "attribute": null}
# entFrom {"begin": 453, "end": 471, "cui": null, "attribute": {"sentence_prob": 0.874, "concept_prob": 0.98}}
# entTo {"begin": 457, "end": 461, "cui": null, "attribute": null}
# entFrom {"begin": 806, "end": 816, "cui": "C0239785 SNOMEDCT_US[14660001000004108]", "attribute": {"sentence_prob": "0.763", "concept_prob": "0.764", "umlsCuiDesc": "Rash of groin"}}
# entTo {"begin": 796, "end": 805, "cui": null, "attribute": null}
# entFrom {"begin": 806, "end": 816, "cui": "C0239785 SNOMEDCT_US[14660001000004108]", "attribute": {"sentence_prob": "0.763", "concept_prob": "0.764", "umlsCuiDesc": "Rash of groin"}}
# entTo {"begin": 806, "end": 811, "cui": null, "attribute": null}
# entFrom {"begin": 1035, "end": 1057, "cui": null, "attribute": {"sentence_prob": 0.912, "concept_prob": 0.998}}
# entTo {"begin": 1021, "end": 1034, "cui": null, "attribute": null}
# entFrom {"begin": 1136, "end": 1157, "cui": null, "attribute": {"sentence_prob": 0.258, "concept_prob": 0.735}}
# entTo {"begin": 1141, "end": 1151, "cui": null, "attribute": null}
# entFrom {"begin": 1163, "end": 1172, "cui": null, "attribute": {"sentence_prob": 0.258, "concept_prob": 0.976}}
# entTo {"begin": 1167, "end": 1172, "cui": null, "attribute": null}
# entFrom {"begin": 1200, "end": 1212, "cui": "C0016436 SNOMEDCT_US[13600006]", "attribute": {"sentence_prob": "0.258", "concept_prob": "0.999", "umlsCuiDesc": "Folliculitis"}}
# entTo {"begin": 1186, "end": 1199, "cui": null, "attribute": null}
# entFrom {"begin": 1465, "end": 1473, "cui": null, "attribute": {"sentence_prob": 0.967, "concept_prob": 0.97}}
# entTo {"begin": 1457, "end": 1464, "cui": null, "attribute": null}
# entFrom {"begin": 1494, "end": 1500, "cui": "C0019342 SNOMEDCT_US[33839006]", "attribute": {"sentence_prob": "0.872", "concept_prob": "0.938", "umlsCuiDesc": "Genital Herpes"}}
# entTo {"begin": 1484, "end": 1493, "cui": null, "attribute": null}
# entFrom {"begin": 156, "end": 170, "cui": "RxNorm=[103395], Generic=[5492]", "attribute": null}
# entTo {"begin": 189, "end": 192, "cui": null, "attribute": null}
# entFrom {"begin": 156, "end": 170, "cui": "RxNorm=[103395], Generic=[5492]", "attribute": null}
# entTo {"begin": 171, "end": 176, "cui": null, "attribute": null}
# entFrom {"begin": 574, "end": 588, "cui": "RxNorm=[103395], Generic=[5492]", "attribute": null}
# entTo {"begin": 589, "end": 594, "cui": null, "attribute": null}
# entFrom {"begin": 1073, "end": 1087, "cui": "RxNorm=[103395], Generic=[5492]", "attribute": null}
# entTo {"begin": 1088, "end": 1093, "cui": null, "attribute": null}
# entFrom {"begin": 1431, "end": 1445, "cui": "RxNorm=[103395], Generic=[5492]", "attribute": null}
# entTo {"begin": 1446, "end": 1451, "cui": null, "attribute": null}
# 3283807389 3283807389.txt.xmi
# edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA ['assertion', 'attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'begin', 'cui', 'end', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# edu.uth.clamp.nlp.typesystem.ClampRelationUIMA ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'entFrom', 'entTo', 'semanticTag', 'type', 'xmiID', 'system', 'note_id', 'corpus', 'filename']
# entFrom {"begin": 362, "end": 379, "cui": null, "attribute": {"sentence_prob": 0.931, "concept_prob": 1.0}}
# entTo {"begin": 353, "end": 361, "cui": null, "attribute": null}
# entFrom {"begin": 362, "end": 379, "cui": null, "attribute": {"sentence_prob": 0.931, "concept_prob": 1.0}}
# entTo {"begin": 362, "end": 370, "cui": null, "attribute": null}
# entFrom {"begin": 584, "end": 607, "cui": null, "attribute": {"sentence_prob": 0.528, "concept_prob": 0.535}}
# entTo {"begin": 577, "end": 583, "cui": null, "attribute": null}
# entFrom {"begin": 584, "end": 607, "cui": null, "attribute": {"sentence_prob": 0.528, "concept_prob": 0.535}}
# entTo {"begin": 601, "end": 607, "cui": null, "attribute": null}
# entFrom {"begin": 609, "end": 614, "cui": "C0687152 SNOMEDCT_US[289114008]", "attribute": {"sentence_prob": "0.528", "concept_prob": "0.996", "umlsCuiDesc": "Does cough"}}
# entTo {"begin": 577, "end": 583, "cui": null, "attribute": null}
# entFrom {"begin": 616, "end": 626, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "0.528", "concept_prob": "0.999", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 577, "end": 583, "cui": null, "attribute": null}
# entFrom {"begin": 616, "end": 626, "cui": "C0008031 SNOMEDCT_US[29857009]", "attribute": {"sentence_prob": "0.528", "concept_prob": "0.999", "umlsCuiDesc": "Chest Pain"}}
# entTo {"begin": 616, "end": 621, "cui": null, "attribute": null}
# entFrom {"begin": 628, "end": 642, "cui": "C0000737 SNOMEDCT_US[21522001]", "attribute": {"sentence_prob": "0.528", "concept_prob": "1.0", "umlsCuiDesc": "Abdominal Pain"}}
# entTo {"begin": 577, "end": 583, "cui": null, "attribute": null}
# entFrom {"begin": 628, "end": 642, "cui": "C0000737 SNOMEDCT_US[21522001]", "attribute": {"sentence_prob": "0.528", "concept_prob": "1.0", "umlsCuiDesc": "Abdominal Pain"}}
# entTo {"begin": 628, "end": 637, "cui": null, "attribute": null}
# entFrom {"begin": 644, "end": 652, "cui": "C0011991 SNOMEDCT_US[62315008, 267060006]", "attribute": {"sentence_prob": "0.528", "concept_prob": "1.0", "umlsCuiDesc": "Diarrhea"}}
# entTo {"begin": 577, "end": 583, "cui": null, "attribute": null}
# entFrom {"begin": 654, "end": 661, "cui": "C0013428 SNOMEDCT_US[49650001]", "attribute": {"sentence_prob": "0.528", "concept_prob": "1.0", "umlsCuiDesc": "Dysuria"}}
# entTo {"begin": 577, "end": 583, "cui": null, "attribute": null}
# entFrom {"begin": 663, "end": 682, "cui": "C0239978 SNOMEDCT_US[15510009]", "attribute": {"sentence_prob": "0.528", "concept_prob": "0.995", "umlsCuiDesc": "Increased frequency of defecation"}}
# entTo {"begin": 577, "end": 583, "cui": null, "attribute": null}
# entFrom {"begin": 663, "end": 682, "cui": "C0239978 SNOMEDCT_US[15510009]", "attribute": {"sentence_prob": "0.528", "concept_prob": "0.995", "umlsCuiDesc": "Increased frequency of defecation"}}
# entTo {"begin": 663, "end": 672, "cui": null, "attribute": null}
# entFrom {"begin": 687, "end": 695, "cui": "C0028734 SNOMEDCT_US[139394000]", "attribute": {"sentence_prob": "0.528", "concept_prob": "0.999", "umlsCuiDesc": "Nocturia"}}
# entTo {"begin": 577, "end": 583, "cui": null, "attribute": null}
# entFrom {"begin": 705, "end": 717, "cui": null, "attribute": {"sentence_prob": 0.934, "concept_prob": 0.991}}
# entTo {"begin": 698, "end": 704, "cui": null, "attribute": null}
# entFrom {"begin": 721, "end": 735, "cui": "C0151315 SNOMEDCT_US[161882006]", "attribute": {"sentence_prob": "0.934", "concept_prob": "0.997", "umlsCuiDesc": "Neck stiffness"}}
# entTo {"begin": 698, "end": 704, "cui": null, "attribute": null}
# entFrom {"begin": 721, "end": 735, "cui": "C0151315 SNOMEDCT_US[161882006]", "attribute": {"sentence_prob": "0.934", "concept_prob": "0.997", "umlsCuiDesc": "Neck stiffness"}}
# entTo {"begin": 721, "end": 725, "cui": null, "attribute": null}
# entFrom {"begin": 759, "end": 778, "cui": null, "attribute": {"sentence_prob": 0.934, "concept_prob": 0.963}}
# entTo {"begin": 698, "end": 704, "cui": null, "attribute": null}
# entFrom {"begin": 759, "end": 778, "cui": null, "attribute": {"sentence_prob": 0.934, "concept_prob": 0.963}}
# entTo {"begin": 756, "end": 758, "cui": null, "attribute": null}
# entFrom {"begin": 880, "end": 884, "cui": "C0242936 SNOMEDCT_US[702897005]", "attribute": {"sentence_prob": "0.779", "concept_prob": "0.956", "umlsCuiDesc": "Pain Clinics"}}
# entTo {"begin": 877, "end": 879, "cui": null, "attribute": null}
# entFrom {"begin": 931, "end": 940, "cui": null, "attribute": {"sentence_prob": 0.983, "concept_prob": 1.0}}
# entTo {"begin": 931, "end": 935, "cui": null, "attribute": null}
# entFrom {"begin": 1993, "end": 2011, "cui": null, "attribute": {"sentence_prob": 0.52, "concept_prob": 0.989}}
# entTo {"begin": 1986, "end": 1992, "cui": null, "attribute": null}
# entFrom {"begin": 2203, "end": 2214, "cui": null, "attribute": {"sentence_prob": 0.349, "concept_prob": 1.0}}
# entTo {"begin": 2183, "end": 2202, "cui": null, "attribute": null}
# entFrom {"begin": 2249, "end": 2271, "cui": null, "attribute": {"sentence_prob": 0.541, "concept_prob": 0.544}}
# entTo {"begin": 2246, "end": 2248, "cui": null, "attribute": null}
# entFrom {"begin": 2612, "end": 2621, "cui": "C0851162 SNOMEDCT_US[312154004]", "attribute": {"sentence_prob": "0.904", "concept_prob": "0.921", "umlsCuiDesc": "Infections of musculoskeletal system"}}
# entTo {"begin": 2587, "end": 2595, "cui": null, "attribute": null}
# entFrom {"begin": 2666, "end": 2684, "cui": null, "attribute": {"sentence_prob": 0.984, "concept_prob": 0.993}}
# entTo {"begin": 2657, "end": 2665, "cui": null, "attribute": null}
# entFrom {"begin": 2666, "end": 2684, "cui": null, "attribute": {"sentence_prob": 0.984, "concept_prob": 0.993}}
# entTo {"begin": 2666, "end": 2672, "cui": null, "attribute": null}
# entFrom {"begin": 2921, "end": 2930, "cui": "C1319805 SNOMEDCT_US[407618000]", "attribute": {"sentence_prob": "0.434", "concept_prob": "0.995", "umlsCuiDesc": "1 to 12 seizures a year"}}
# entTo {"begin": 2913, "end": 2920, "cui": null, "attribute": null}
# entFrom {"begin": 3215, "end": 3221, "cui": "C0018021 SNOMEDCT_US[3716002]", "attribute": {"sentence_prob": "0.997", "concept_prob": "0.997", "umlsCuiDesc": "Goiter"}}
# entTo {"begin": 3212, "end": 3214, "cui": null, "attribute": null}
# entFrom {"begin": 3791, "end": 3808, "cui": null, "attribute": {"sentence_prob": 0.996, "concept_prob": 0.997}}
# entTo {"begin": 3788, "end": 3790, "cui": null, "attribute": null}
# entFrom {"begin": 3730, "end": 3738, "cui": "C0042890, RxNorm=[11262], Generic=[11262]", "attribute": null}
# entTo {"begin": 3707, "end": 3718, "cui": null, "attribute": null}
# entFrom {"begin": 1569, "end": 1573, "cui": null, "attribute": null}
# entTo {"begin": 1558, "end": 1568, "cui": "C0019046", "attribute": {"sentence_prob": "0.586", "concept_prob": "0.991", "umlsCuiDesc": "Hemoglobin"}}
# entFrom {"begin": 1587, "end": 1590, "cui": null, "attribute": null}
# entTo {"begin": 1575, "end": 1586, "cui": "C0023508", "attribute": {"sentence_prob": "0.586", "concept_prob": "0.984", "umlsCuiDesc": "White Blood Cell Count procedure"}}
# entFrom {"begin": 1640, "end": 1643, "cui": null, "attribute": null}
# entTo {"begin": 1619, "end": 1639, "cui": "C0948762", "attribute": {"sentence_prob": "0.586", "concept_prob": "0.996", "umlsCuiDesc": "Absolute neutrophil count"}}
# entFrom {"begin": 1689, "end": 1692, "cui": null, "attribute": null}
# entTo {"begin": 1679, "end": 1688, "cui": "C0005821", "attribute": {"sentence_prob": "0.886", "concept_prob": "1.0", "umlsCuiDesc": "Blood Platelets"}}
# entFrom {"begin": 1701, "end": 1704, "cui": null, "attribute": null}
# entTo {"begin": 1694, "end": 1700, "cui": "C0037473", "attribute": {"sentence_prob": "0.886", "concept_prob": "0.994", "umlsCuiDesc": "Sodium"}}
# entFrom {"begin": 1748, "end": 1751, "cui": null, "attribute": null}
# entTo {"begin": 1734, "end": 1747, "cui": "C0555903", "attribute": {"sentence_prob": "0.886", "concept_prob": "0.999", "umlsCuiDesc": "Total protein measurement"}}
# entFrom {"begin": 1761, "end": 1764, "cui": null, "attribute": null}
# entTo {"begin": 1753, "end": 1760, "cui": "C0017725", "attribute": {"sentence_prob": "0.886", "concept_prob": "1.0", "umlsCuiDesc": "Glucose"}}
# entFrom {"begin": 1775, "end": 1778, "cui": null, "attribute": null}
# entTo {"begin": 1766, "end": 1774, "cui": "C0201850", "attribute": {"sentence_prob": "0.886", "concept_prob": "1.0", "umlsCuiDesc": "Alkaline phosphatase measurement"}}
# entFrom {"begin": 1784, "end": 1786, "cui": null, "attribute": null}
# entTo {"begin": 1780, "end": 1783, "cui": "C0004002", "attribute": {"sentence_prob": "0.886", "concept_prob": "1.0", "umlsCuiDesc": "Aspartate Transaminase"}}
# entFrom {"begin": 1804, "end": 1807, "cui": null, "attribute": null}
# entTo {"begin": 1788, "end": 1803, "cui": "C0201913", "attribute": {"sentence_prob": "0.886", "concept_prob": "0.998", "umlsCuiDesc": "Bilirubin, total measurement"}}
# entFrom {"begin": 1820, "end": 1823, "cui": null, "attribute": null}
# entTo {"begin": 1809, "end": 1819, "cui": "C0010294", "attribute": {"sentence_prob": "0.886", "concept_prob": "0.996", "umlsCuiDesc": "Creatinine"}}
# entFrom {"begin": 1847, "end": 1850, "cui": null, "attribute": null}
# entTo {"begin": 1838, "end": 1846, "cui": "C0596019", "attribute": {"sentence_prob": "0.886", "concept_prob": "1.0", "umlsCuiDesc": "Chloride Ion"}}
# entFrom {"begin": 1856, "end": 1858, "cui": null, "attribute": null}
# entTo {"begin": 1852, "end": 1855, "cui": "C0007012", "attribute": {"sentence_prob": "0.886", "concept_prob": "1.0", "umlsCuiDesc": "Carbon Dioxide"}}
# entFrom {"begin": 1864, "end": 1868, "cui": null, "attribute": null}
# entTo {"begin": 1860, "end": 1863, "cui": "C0005845", "attribute": {"sentence_prob": "0.886", "concept_prob": "0.999", "umlsCuiDesc": "Blood urea nitrogen measurement"}}
# entFrom {"begin": 1874, "end": 1878, "cui": null, "attribute": null}
# entTo {"begin": 1870, "end": 1873, "cui": "C0525032", "attribute": {"sentence_prob": "0.886", "concept_prob": "0.999", "umlsCuiDesc": "International Normalized Ratio"}}
# entFrom {"begin": 1885, "end": 1889, "cui": null, "attribute": null}
# entTo {"begin": 1880, "end": 1884, "cui": "C0030605", "attribute": {"sentence_prob": "0.886", "concept_prob": "0.98", "umlsCuiDesc": "Activated Partial Thromboplastin Time measurement"}}
# done!

# %%
# create tables for cTAKES UMLS concept -> mention table
# https://stackoverflow.com/questions/12680754/split-explode-pandas-dataframe-string-entry-to-separate-rows

def mk_ctakes_concepts(sql, table_name):
    import pymysql
    import pandas as pd
    from sqlalchemy.engine import create_engine

    engine = create_engine('mysql+pymysql://gms:nej123@localhost/test', pool_pre_ping=True)

    df = pd.read_sql(sql, engine)

    # MetaMap
    b = pd.DataFrame(df.cuiConcepts.str.split(' ').tolist(), index=df.cuiConcepts).stack()
    b = b.reset_index()[[0, 'cuiConcepts']] # var1 variable is currently labeled 0
    b.columns = ['linked_id', 'cuiConcepts'] # renaming var1
    
    # CTAKES:
     
    #b = pd.DataFrame(df.ontologyConceptArr.str.split(' ').tolist(), index=df.ontologyConceptArr).stack()
    #b = b.reset_index()[[0, 'ontologyConceptArr']] # var1 variable is currently labeled 0
    #b.columns = ['linked_id', 'ontologyConceptArr'] # renaming var1
    

    c = pd.merge(df, b)
   
    c.to_sql(table_name, engine, if_exists="replace") 

    print(c[0:2])

''' TABLES to make
sql = "SELECT * FROM test.met_org_negation"
table_name = 'mm_negation'

mk_ctakes_concepts(sql, table_name)

'''
'''
sql = "SELECT * FROM test.cta_disease"
table_name = 'cTAKES_disease'

mk_ctakes_concepts(sql, table_name)

sql = "SELECT * FROM test.cta_med"
table_name = 'cTAKES_medication'

mk_ctakes_concepts(sql, table_name)


sql = "SELECT * FROM test.cta_proc"
table_name = 'cTAKES_procedure'
mk_ctakes_concepts(sql, table_name)


sql = "SELECT * FROM test.cta_sign_symptom"
table_name = 'cTAKES_sign_symptom'

mk_ctakes_concepts(sql, table_name)

sql = "SELECT * FROM test.cta_anatomical_site"
table_name = 'cTAKES_anatomical_site'

mk_ctakes_concepts(sql, table_name)
'''

# %%
# fix XMI, adding "id" for those with linked features

def add_attribute_sys_type(regexpatterns):
    import re, os, glob, path
    import regex

    #directory_to_parse = '/Users/gms/development/nlp/nlpie/data/amia-2019/i2b2/quarantine/'

    #for fname in glob.iglob("/Users/gms/development/nlp/nlpie/data/amia-2019/i2b2/quarantine/period2/*.txt"):

    for fname in glob.iglob("/Users/gms/development/nlp/nlpie/data/amia-2019/analysis/mipacq/rerun_post_validation/metamap_out/*.txt.xmi"):

        # get filename and use for processed output filename
        t = os.path.basename(fname)
        cd = os.path.dirname(fname)
        u = t.split('.')[0] + '-v2.txt.xmi'
        #print(t, cd)

        #print(t)
        with open(fname) as f:
            with open(cd + '/' + u, 'w') as f2:
                for line in f:
                    for r in regexpatterns:
                        line = re.sub(r, r + ' id="0"', line)
                    f2.write(line)
    

#regexpatterns = [r"refsem:UmlsConcept"]
#regexpatterns = [r"ts2:CuiConcept"]
#regexpatterns = [r"ts2:Negation"]

#add_attribute_sys_type(regexpatterns)

# %%
# test dkpro-cassis
from cassis import *
def test_dkpro(fname, dir_test, ts_test, view_name):
    with open(ts_test + 'TypeSystem.xml', 'rb') as f:
        typesystem = load_typesystem(f)
    with open(dir_test + fname, 'rb') as f:
        cas = load_cas_from_xmi(f, typesystem=typesystem)
    view = cas.get_view(view_name)
    print([x for x in view.select_all()])
    #print([x for x in view.select("org.apache.ctakes.typesystem.type.refsem.UmlsConcept")])


# dir_test = '/Users/gms/development/nlp/nlpie/data/amia-2019/analysis/mipacq/metamap_out/'
# view_name = "_InitialView"
# ts_test = "/Users/gms/development/nlp/nlpie/data/amia-2019/typesystems/metamap/"
# fname = '3283236649-v1.txt.xmi'
# test_dkpro(fname, dir_test, ts_test, view_name)

# %%
# create tables for
# https://stackoverflow.com/questions/12680754/split-explode-pandas-dataframe-string-entry-to-separate-rows

def get_analytical_set(sql):
    import pymysql
    import pandas as pd
    from sqlalchemy.engine import create_engine

    engine = create_engine('mysql+pymysql://gms:nej123@localhost/test', pool_pre_ping=True)

    df = pd.read_sql(sql, engine)
    
    return df

#GENERATE analytical tables
'''
analytical_cui = pd.DataFrame()

sql = "SELECT * FROM test.biomedicus_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])

frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

sql = "SELECT * FROM test.clamp_all_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])

frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

sql = "SELECT * FROM test.ctakes_all_types_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])

frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

sql = "SELECT * FROM test.metamap_all_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])
frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

print(analytical_cui[0:1])
analytical_cui.to_csv('/Users/gms/development/nlp/nlpie/data/amia-2019/output/analytical_cui_mipacq_concepts.csv')
'''

# %%
# clean up cui list in clamp
#df['stridx']=df.index


#print(df[df['cui'].str.contains(',')==True])

#df['new_cui' ] = np.where(df.cui.str.contains(','), df['cui'].str.split(r'\s*,\s*|\s*\.\s*').str[0], df['cui'])

#print(df['cui'])
#print(df[df['cui'].str.contains(',')==False])

#new = df.rename(columns={'cui': 'old_cui', 'new_cui': 'cui'}).copy() 
#new.to_csv('/Users/gms/development/nlp/nlpie/data/amia-2019/output/analytical_cui_mipacq_concepts_new.csv')
#writer = pd.ExcelWriter('/Users/gms/development/nlp/nlpie/data/amia-2019/output/ensemble/merged_metrics.xlsx')
