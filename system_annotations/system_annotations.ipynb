# %%
# annotation class for UIMA systems
class AnnotationSystems(object):
    """
    CAS XMI Annotations of interest
    
    """
    
    def __init__(self):
        
        """ 
        annotation base types
        """
        
        self.biomedicus_dir = "biomedicus_out/"
        self.biomedicus_types = ["biomedicus.v2.UmlsConcept",
                                 "biomedicus.v2.Negated"]#,
                                 #"biomedicus.v2.Acronym",
                                 #"biomedicus.v2.TemporalPhrase"]
        
        
        self.clamp_dir = "clamp_out/"
        #self.clamp_dir = "Annotated_XMI/"
        self.clamp_types = ["edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA",
                            "edu.uth.clamp.nlp.typesystem.ClampRelationUIMA"]
        
        
        self.ctakes_dir = "ctakes_out/"
        self.ctakes_types = ["org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention",
                             "org.apache.ctakes.typesystem.type.textsem.MedicationMention",
                             "org.apache.ctakes.typesystem.type.textsem.ProcedureMention",
                             "org.apache.ctakes.typesystem.type.textsem.SignSymptomMention",
                             "org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention"]#,
                             #"org.apache.ctakes.typesystem.type.textsem.DateAnnotation",
                             #"org.apache.ctakes.typesystem.type.textsem.MeasurementAnnotation"]
       
        self.metamap_dir = "metamap_out/"
        self.metamap_types = ["org.metamap.uima.ts.Candidate",
                              #"org.metamap.uima.ts.CuiConcept",
                              "org.metamap.uima.ts.Negation"]
                
       
    def get_system_type(self, system):
        
        """
        return system types
        """
        
        if system == "biomedicus":
            view = "Analysis"
            
        else:
            view = "_InitialView"

        if system == 'biomedicus':
            types = self.biomedicus_types
            output = self.biomedicus_dir

        elif system == 'clamp':
            types = self.clamp_types
            output = self.clamp_dir

        elif system == 'ctakes':
            types = self.ctakes_types
            output = self.ctakes_dir

        elif system == 'metamap':
            types = self.metamap_types
            output = self.metamap_dir
            
        return types, view, output
    
annSys = AnnotationSystems()

# extract attributes from cas Annotation object
def get_attribs(v):
    attribs = []
    for sentence in v:
        #print(sentence)
        for s in sentence.__dir__():
            if '__' not in s:
                if s not in attribs:
                    #print(s)
                    attribs.append(s)
                else:
                    break

    return attribs

def get_cols_to_keep(system, t):
    
    if system == 'biomedicus':
        
        if 'Temporal' in t:
            cols_to_keep = ['begin', 'end', 'system', 'note_id', 'corpus',
                            'filename', 'type']
            
        # umlsconcept
        if 'Umls' in t:
            cols_to_keep = ['begin', 'confidence', 'cui', 'end', 'tui',
                            'type', 'system', 'note_id', 'corpus',
                            'filename']

        # acronym
        if 'Acronym' in t:
            cols_to_keep = ['begin', 'end', 'score', 'text', 'type',
                            'system', 'note_id', 'corpus', 'filename']

        # negated
        if 'Negated' in t:
            cols_to_keep = ['begin', 'cueTerms', 'end', 'type', 
                           'system', 'note_id', 'corpus', 'filename']
        
    elif system == 'clamp':
        #NE uima
        if 'NameEntityUIMA' in t:
            cols_to_keep = ['assertion', 'attribute', 'begin',
                           'cui', 'end', 'semanticTag', 'type', 
                           'system', 'note_id', 'corpus', 'filename', 'umlsCuiDesc', 
                            'concept_prob', 'sentence_prob']

        # relation uima: TODO -> deal with named tuples!
        if 'Relation' in t:
#             cols_to_keep = ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'cui', 'entFrom', 'entTo',
#                            'semanticTag', 'type', 'xmiID', 'system', 'note_id',
#                            'corpus', 'filename']
            cols_to_keep = ['begin', 'end', 'cui', 'umlsCuiDesc', 'semanticTag', 'type', 'system', 'note_id',
                           'corpus', 'filename', 'src']
        
    elif system == 'ctakes':
        # disease
        if 'Disease' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end', 'historyOf', 
                           'ontologyConceptArr', 'polarity', 'type', 'typeID', 'uncertainty',
                           'system', 'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']

        # medication
        if 'Medication' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end',
                           'historyOf', 'ontologyConceptArr', 'polarity',
                           'type', 'uncertainty', 'system',
                           'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']

        # proc
        if 'Procedure' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end',
                           'historyOf', 'ontologyConceptArr', 'polarity',
                           'type', 'uncertainty', 'system',
                           'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']

        # sign
        if 'SignSymptom' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end',
                           'historyOf', 'ontologyConceptArr', 'polarity',
                           'type', 'uncertainty', 'system',
                           'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']

        # anatomy
        if 'Anatomical' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end',
                           'historyOf', 'ontologyConceptArr', 'polarity',
                           'type', 'uncertainty', 'system',
                           'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']
            
        if 'Date' in t:
            cols_to_keep = ['begin', 'end', 'type', 'confidence', 'historyOf',  
                           'polarity', 'uncertainty', 'corpus', 'note_id', 'filename', 'system']
        
        if 'Measurement' in t:
            cols_to_keep = ['begin', 'end', 'type', 'confidence', 'historyOf',  
                           'polarity', 'uncertainty', 'corpus', 'note_id', 'filename', 'system']
        
    elif system == 'metamap':
        #candidate
        if 'Candidate' in t:
            cols_to_keep = ['begin', 'concept', 'cui', 'end', 'matchedwords',
                           'preferred', 'score', 'semanticTypes', 'type', 'system', 'note_id',
                           'corpus', 'filename']

        #cuiconcept
        if 'CuiConcept' in t:
            cols_to_keep = ['id', 'negExConcept', 'negExCui', 'type', 'xmiID',
                           'system', 'note_id', 'corpus', 'filename']

        #negation
        if 'Negation' in t:
            cols_to_keep = ['begin', 'cuiConcepts', 'end', 'cui', 'cuiConcept',
                           'ncSpans', 'negTrigger', 'negType',
                           'type', 'system', 'note_id', 'corpus', 'filename']
    
    else:
        cols_to_keep = []

    return cols_to_keep

# %%
def init_cassis(system, typesystem):
   
    #tic=timeit.default_timer() 

    print(system)

    # types for metamap

    if system == 'metamap':
        t = typesystem.create_type(name='org.apache.uima.examples.SourceDocumentInformation', supertypeName='uima.tcas.Annotation')
        typesystem.add_feature(t, name='uri', rangeTypeName='uima.cas.String')
        typesystem.add_feature(t, name="offsetInSource", rangeTypeName="uima.cas.Integer")
        typesystem.add_feature(t, name="documentSize", rangeTypeName="uima.cas.Integer")
        typesystem.add_feature(t, name="lastSegment", rangeTypeName="uima.cas.Integer")

    # features for ctakes

    if system == 'ctakes':
        t = typesystem.get_type('org.apache.ctakes.typesystem.type.structured.Metadata')
        typesystem.add_feature(t, name='patientIdentifier', rangeTypeName='uima.cas.String')
        
        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.SignSymptomMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.MedicationMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.ProcedureMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

# %%
# sofa -> db
def write_sofa(u):
    d = {}
    d["note_id"] = str(u)
    d["sofa"] = view.sofa_string
    d["corpus"] = corpus

    # does it exist?
    if engine.dialect.has_table(engine, "sofas"):
        sql = text("SELECT * FROM test.sofas WHERE note_id = :e1")
        resp = engine.execute(sql, e1=u).fetchall()
    else:
        resp = []

    if len(resp) == 0:            
        #pd.DataFrame(d, index=[0]).to_sql("sofas", engine, if_exists="append")  
        pd.DataFrame(d, index=[0]).to_sql("sofas", engine, if_exists="append")  
        

def get_dict(keys, sentence, d):
    for i in range(len(keys)):
        key = keys[i]
        val = sentence.__getattribute__(keys[i])
        d[key] = val
    return d

def add_keys(df, system, t, u, corpus, fname):
    df["system"] = system
    df["type"] = t
    df["note_id"] = u
    df["corpus"] = corpus
    df["filename"] = fname
    
    return df

def append_to_df(df, d):
    import pandas as pd
    frames = [ df, pd.DataFrame(d, index=[0]) ]
    df = pd.concat(frames, ignore_index=True)
    
    return df

# %%
#%%time
# parse system annotations
def main():
    import os, glob
    import pymysql
    import pandas as pd
    import json
    from sqlalchemy.engine import create_engine
    from sqlalchemy.sql import text
    from cassis import load_typesystem, load_cas_from_xmi

    # connection string
    engine = create_engine('mysql+pymysql://gms:nej123@localhost/mhealth', pool_pre_ping=True)
    systems = ["clamp", "metamap", "ctakes", "biomedicus"]
    #systems = ['ctakes']
    
    corpora = ["fairview"]
    parse_to_sql = True
    
    if parse_to_sql:
        
        for corpus in corpora:
            print("CORPUS:", corpus)

            for system in systems:

                print("SYSTEM:", system)

                types, view_, output = annSys.get_system_type(system)
                
                dir_test = '/Users/gms/development/nlp/nlpie/scripts/jupyter/ensembling/system_annotations/typesystems/' + system + '/'

                with open(dir_test + 'TypeSystem.xml', 'rb') as f:
                    typesystem = load_typesystem(f)
                
                init_cassis(system, typesystem)
                
                # parse directory
                if corpus in ["i2b2", "mipacq"]:
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/ensembling-u01/' + corpus + '/rerun-november-2019/' +  system + '_out/' #data_to_analyze/all/'
                
                elif corpus == 'fairview':
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/ensembling-u01/' + corpus + '/system_annotations/data_in_preprocessed/' +  system + '_out/'#data_to_analyze/all/'
               
                elif 'clinical_trial' in corpus:
                    # if parsing gold standard, change to_sql below to ensure proper target directory
                    #directory_to_parse = '/Users/gms/development/nlp/nlpie/data/clinical_trial2/' +  system + '_out/'
                    #directory_to_parse = '/Users/gms/development/nlp/nlpie/data/clinical_trial2/gold_standard/'
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/clinical_trial2/bert-output/'
                else:
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/mimic/'
                    
                print(directory_to_parse)

                for fname in glob.glob(directory_to_parse + '/*.xmi'):
                #for fname in glob.glob(directory_to_parse + '/527982345.txt.xmi'):

                    file = os.path.basename(fname)
                    u = file.split('.')[0]

                    print(u)

                    # load cas
                    with open(directory_to_parse + file, 'rb') as f:
                        cas = load_cas_from_xmi(f, typesystem=typesystem)

                    # load view
                    view = cas.get_view(view_)
                    
                    # write sofa object here:
                    #write_sofa(u)

                    for t in types:
                        print("TYPE:", t)
                       
                        # get list for filtering df
                        cols_to_keep = get_cols_to_keep(system, t)
                        
                        attribs = get_attribs(view.select(t))
                        x = t.split('.')
                        table_name = system[0:3] + '_' + x[0] + '_' + x[len(x)-1]

                        # Annotation object -> dataframe
                        def get_df(v, attribs):
                            df = pd.DataFrame()
                            d = dict() 

                            # only parse if type exists in file
                            if view.select(t):
                                for sentence in view.select(t):
                                    
                                    dd = dict()
                                    if t == 'org.metamap.uima.ts.Negation':
                                        keys = ['cuiConcepts', 'ncSpans', 'negTrigger', 'negType']
                                        d = get_dict(keys, sentence, d)

                                        if len(d['cuiConcepts']) == len(d['ncSpans']):
                                             for x in range(len(d['cuiConcepts'])):
                                                dd['cui'] = d['cuiConcepts'][x].negExCui 
                                                dd['concept'] = d['cuiConcepts'][x].negExConcept 
                                                dd['begin'] = d['ncSpans'][x].begin 
                                                dd['end'] = d['ncSpans'][x].end
                                                dd['negTrigger'] = d['negTrigger']
                                                dd['negType'] = d['negType']
                                                dd['cuiConcepts'] = ' '.join(map(str,d['cuiConcepts']))
                                                dd['ncSpans'] = ' '.join(map(str,d['ncSpans']))
                                            
                                                df = append_to_df(df, dd)
                                                df = add_keys(df, system, t, u, corpus, fname)
                                            
                                        elif len(d['cuiConcepts']) > len(d['ncSpans']) and len(d['ncSpans']) == 1:
                                            for x in range(len(d['cuiConcepts'])):
                                                dd['cui'] = d['cuiConcepts'][x].negExCui 
                                                dd['concept'] = d['cuiConcepts'][x].negExConcept
                                                dd['begin'] = d['ncSpans'][0].begin
                                                dd['end'] = d['ncSpans'][0].end
                                                dd['negTrigger'] = d['negTrigger']
                                                dd['negType'] = d['negType']
                                                dd['cuiConcepts'] = ' '.join(map(str,d['cuiConcepts']))
                                                dd['ncSpans'] = ' '.join(map(str,d['ncSpans']))
                                                
                                                df = append_to_df(df, dd)
                                                df = add_keys(df, system, t, u, corpus, fname)
                                            
                                                
                                        elif len(d['cuiConcepts']) < len(d['ncSpans']) and len(d['cuiConcepts']) == 1:
                                            for x in range(len(d['ncSpans'])):
                                                dd['cui'] = d['cuiConcepts'][0].negExCui 
                                                dd['concept'] = d['cuiConcepts'][0].negExConcept
                                                dd['begin'] = d['ncSpans'][x].begin
                                                dd['end'] = d['ncSpans'][x].end
                                                dd['negTrigger'] = d['negTrigger']
                                                dd['negType'] = d['negType']
                                                dd['cuiConcepts'] = ' '.join(map(str,d['cuiConcepts']))
                                                dd['ncSpans'] = ' '.join(map(str,d['ncSpans']))
                                                
                                                df = append_to_df(df, dd)
                                                df = add_keys(df, system, t, u, corpus, fname)
                                                
                                        else:
                                            print('Error: MetaMap Negation', d)
                                    
                                    elif t == 'edu.uth.clamp.nlp.typesystem.ClampRelationUIMA':
                                        keys = ['semanticTag', 'entTo', 'entFrom']
                                        d = get_dict(keys, sentence, d)
                                        
                                        if d['semanticTag'] == 'NEG_Of':
                                            #print(d['entTo'], '\n', d['entFrom'])
                                            attribute =  json.loads(d['entFrom'].attribute)
                                            if 'umlsCuiDesc' in attribute:
                                                dd['cui'] = d['entFrom'].cui.split()[0].replace(',','')  
                                                dd['concept'] = attribute['umlsCuiDesc']
                                                dd['begin'] = d['entFrom'].begin
                                                dd['end'] = d['entFrom'].end
                                                dd['semanticTag'] = d['semanticTag']
                                                dd['entTo'] = str(d['entTo'])
                                                dd['entFrom'] = str(d['entFrom'])
                                                
                                                df = append_to_df(df, dd)
                                                df = add_keys(df, system, t, u, corpus, fname)
                                        
                                    elif t == 'biomedicus.v2.Negated':
                                        keys = ['begin', 'end']
                                        d = get_dict(keys, sentence, d)
                                        df = append_to_df(df, d)
                                        df = add_keys(df, system, t, u, corpus, fname)
                                        
                                    elif t == 'biomedicus.v2.UmlsConcept':
                                        keys = ['begin', 'end', 'cui', 'tui', 'confidence']
                                        d = get_dict(keys, sentence, d)
                                        
                                        df = append_to_df(df, d)
                                        df = add_keys(df, system, t, u, corpus, fname)
                                    
                                    # no labvalue -> no UMLS info
                                    elif t == 'edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA':
                                        keys = ['assertion', 'cui', 'begin', 'end', 'attribute', 'semanticTag']
                                        d = get_dict(keys, sentence, d)
                                        
                                        if 'attribute' in d and d['attribute']:
                                            attribute =  json.loads(d['attribute'])
                                            #if d['assertion'] == 'present':
                                            if 'umlsCuiDesc' in attribute:
                                                dd['concept'] = attribute['umlsCuiDesc']
                                                dd['sentence_prob'] = attribute['sentence_prob'] 
                                                dd['concept_prob'] = attribute['concept_prob']
                                                dd['assertion'] = d['assertion']
                                                dd['cui'] = d['cui'].split()[0].replace(',','') 
                                                dd['begin'] = d['begin']
                                                dd['end'] = d['end']
                                                dd['semanticTag'] = d['semanticTag']
                                                dd['attribute'] = str(d['attribute'])

                                                df = append_to_df(df, dd)
                                                df = add_keys(df, system, t, u, corpus, fname)
                                        else:
                                            if d['semanticTag'] == 'drug':
                                                if d['cui'] and 'C' in d['cui']:
                                                    dd['cui'] = str(d['cui'].split()[0]).replace(',','') 
                                                    dd['begin'] = d['begin']
                                                    dd['end'] = d['end']
                                                    dd['semanticTag'] = d['semanticTag']

                                                    df = append_to_df(df, dd)
                                                    df = add_keys(df, system, t, u, corpus, fname)
                                            
                                                    
                                    elif 'Mention' in t:
                                        keys = ['begin', 'conditional', 'confidence', 'end', 'historyOf', 'ontologyConceptArr', 'polarity', 
                                                'uncertainty']
                                        d = get_dict(keys, sentence, d)
                                        
                                        for x in range(len(d['ontologyConceptArr'])):
                                                dd['cui'] = d['ontologyConceptArr'][x].cui
                                                dd['tui'] = d['ontologyConceptArr'][x].tui
                                                dd['concept'] = d['ontologyConceptArr'][x].preferredText
                                                dd['ontologyConceptArr'] = ' '.join(map(str,d['ontologyConceptArr']))
                                                dd['begin'] = d['begin']
                                                dd['end'] = d['end']
                                                dd['conditional'] = d['conditional']
                                                dd['confidence'] = d['confidence']
                                                dd['historyOf'] = d['historyOf']
                                                dd['polarity'] = d['polarity']
                                                dd['uncertainty'] = d['uncertainty']                    
                                                                    
                                                df = append_to_df(df, dd)
                                                df = add_keys(df, system, t, u, corpus, fname)
                                                
                                    elif t == 'org.metamap.uima.ts.Candidate':
                                        keys =  ['begin', 'concept', 'cui', 'end',
                                                 'preferred', 'score', 'semanticTypes', 'matchedwords']
                                        d = get_dict(keys, sentence, d)
                                        d['semanticTypes'] = " ".join(d['semanticTypes'])
                                        d['matchedwords'] = " ".join(d['matchedwords'])
                                        
                                        df = append_to_df(df, d)
                                        df = add_keys(df, system, t, u, corpus, fname)
                            
                            return df
                            
                        annotations = get_df(view.select(t), attribs)
                        
                        # write to database
                        #annotations = annotations[cols_to_keep]
                        #annotations.to_csv('~/Desktop/test.csv')
                        annotations.to_sql(table_name, engine, if_exists="append") 
                        
    # write out annotations for non-cui tables
    else:
        
        sys_ann_other = pd.DataFrame()
        for system in systems:
                
            types, view_, output = annSys.get_system_type(system)
            print("SYSTEM:", system)
           
            for t in types:

                x = t.split('.')
                table_name = system[0:3] + '_' + x[0] + '_' + x[len(x)-1]

                sql = "SELECT * FROM test." + table_nam 
                df = pd.read_sql(sql, engine)

                cols_to_keep = ['begin', 'end', 'type', 'system', 'note_id', 'corpus', 'filename']
                #print(system, t, table_name, list(df[cols_to_keep].columns.values))
                
                frames = [ sys_ann_other, df[cols_to_keep] ]
                sys_ann_other = pd.concat(frames, ignore_index=True)
        
        print(sys_ann_other.drop_duplicates())
        sys_ann_other.drop_duplicates().to_csv('/Users/gms/development/nlp/nlpie/data/amia-2019/output/analytical_' + corpus + '.csv')


if __name__ == '__main__':
    # %prun main()
    print('done!')
    pass
    main()
# Out:
# CORPUS: fairview
# SYSTEM: clamp
# clamp
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/clamp_out/
# 0029014353
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002131938
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0006468380
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000513005
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000323786
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000202738
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001004137
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001117827
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002442225
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002518956
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001157129
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002204202
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001053477
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001038369
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0040006867
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000469349
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000521643
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000089745
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000409169
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001908516
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0034221950
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000220714
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0007315616
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000473442
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002634827
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0026042553
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000234695
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000235208
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0004058897
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001157311
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001112285
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002340241
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0030906420
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0007340048
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000200926
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000258427
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0022008933
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0050143945
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000198143
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000327956
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# SYSTEM: metamap
# metamap
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/metamap_out/
# 0002204202
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000513005
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000200926
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000202738
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0029014353
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002518956
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001157129
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000089745
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001053477
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001157311
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000234695
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000258427
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000409169
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0026042553
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000235208
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001038369
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002131938
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000469349
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001004137
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002442225
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0006468380
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000521643
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001908516
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0030906420
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000150693
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000473442
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002634827
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0004058897
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0022008933
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000198143
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001117827
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001112285
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002340241
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0007315616
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000220714
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000323786
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0040006867
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0007340048
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0034221950
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0050143945
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000327956
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# SYSTEM: ctakes
# /anaconda3/lib/python3.7/site-packages/cassis/typesystem.py:268: UserWarning: Feature with name [ontologyConceptArr] already exists in parent!
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/cassis/typesystem.py:268: UserWarning: Feature with name [id] already exists in parent!
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/cassis/typesystem.py:268: UserWarning: Feature with name [subject] already exists in parent!
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/cassis/typesystem.py:268: UserWarning: Feature with name [discoveryTechnique] already exists in parent!
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/cassis/typesystem.py:268: UserWarning: Feature with name [polarity] already exists in parent!
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/cassis/typesystem.py:268: UserWarning: Feature with name [uncertainty] already exists in parent!
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/cassis/typesystem.py:268: UserWarning: Feature with name [conditional] already exists in parent!
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/cassis/typesystem.py:268: UserWarning: Feature with name [generic] already exists in parent!
#   warnings.warn(msg)
# /anaconda3/lib/python3.7/site-packages/cassis/typesystem.py:268: UserWarning: Feature with name [historyOf] already exists in parent!
#   warnings.warn(msg)
# ctakes
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/ctakes_out/
# 0002204202
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000513005
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000200926
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000202738
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0029014353
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002518956
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001157129
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000089745
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001053477
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001157311
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000234695
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000258427
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000409169
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0026042553
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000235208
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001038369
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002131938
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000469349
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001004137
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002442225
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0006468380
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000521643
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001908516
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0030906420
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000150693
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000473442
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002634827
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0004058897
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0022008933
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000198143
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001117827
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001112285
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002340241
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0007315616
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000220714
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000323786
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0040006867
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0007340048
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0034221950
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0050143945
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000327956
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# SYSTEM: biomedicus
# biomedicus
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/biomedicus_out/
# 0002204202
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000513005
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000200926
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000202738
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0029014353
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0002518956
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0001157129
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000089745
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0001053477
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0001157311
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000234695
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000258427
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000409169
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0026042553
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000235208
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0001038369
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0002131938
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000469349
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0001004137
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0002442225
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0006468380
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000521643
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0001908516
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0030906420
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000150693
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000473442
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0002634827
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0004058897
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0022008933
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000198143
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0001117827
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0001112285
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0002340241
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0007315616
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000220714
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000323786
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0040006867
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0007340048
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0034221950
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0050143945
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
# 0000327956
# TYPE: biomedicus.v2.UmlsConcept
# TYPE: biomedicus.v2.Negated
#  done!
# CORPUS: fairview
# SYSTEM: clamp
# clamp
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/clamp_out/
# 0029014353
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002131938
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0006468380
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000513005
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000323786
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000202738
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001004137
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001117827
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002442225
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002518956
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001157129
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002204202
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001053477
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001038369
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0040006867
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000469349
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000521643
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000089745
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000409169
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001908516
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0034221950
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000220714
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0007315616
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000473442
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002634827
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0026042553
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000234695
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000235208
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0004058897
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001157311
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0001112285
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0002340241
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0030906420
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0007340048
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000200926
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000258427
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0022008933
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0050143945
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000198143
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# 0000327956
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# SYSTEM: metamap
# metamap
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/metamap_out/
# 0002204202
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000513005
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000200926
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000202738
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0029014353
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002518956
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001157129
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000089745
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001053477
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001157311
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000234695
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000258427
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000409169
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0026042553
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000235208
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001038369
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002131938
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000469349
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001004137
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002442225
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0006468380
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000521643
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001908516
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0030906420
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000150693
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000473442
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002634827
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0004058897
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0022008933
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000198143
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001117827
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0001112285
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0002340241
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0007315616
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000220714
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000323786
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0040006867
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0007340048
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0034221950
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0050143945
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# 0000327956
# TYPE: org.metamap.uima.ts.Candidate
# TYPE: org.metamap.uima.ts.Negation
# SYSTEM: ctakes
# ctakes
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/ctakes_out/
# 0002204202
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000513005
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000200926
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000202738
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0029014353
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002518956
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001157129
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000089745
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001053477
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001157311
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000234695
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000258427
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000409169
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0026042553
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000235208
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001038369
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002131938
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000469349
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001004137
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002442225
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0006468380
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000521643
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001908516
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0030906420
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000150693
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000473442
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002634827
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0004058897
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0022008933
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0000198143
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001117827
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0001112285
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0002340241
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.ProcedureMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.SignSymptomMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention
# 0007315616
# TYPE: org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention
# TYPE: org.apache.ctakes.typesystem.type.textsem.MedicationMention
# ...
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_MeasurementAnnotation-21>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_Time-16>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_Entity-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_ElementRelation-13>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_TopTreebankNode-16>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_CONJP-8>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_ContextAnnotation-24>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_PunctuationToken-13>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_VP-8>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_ResultOf-12>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_LocationOf-12>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_BinaryTextRelation-12>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_ElementRelation-12>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_Entity-14>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_Relation-10>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_DiseaseDisorder-26>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_Lab-20>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_Element-14>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_LabReferenceRange-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_BodySide-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_AnatomicalSite-16>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_MedicationFrequency-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_MedicationStatusChange-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_ProcedureMethod-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_LabValue-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_PersonTitleAnnotation-20>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_ContextAnnotation-22>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_MedicationRoute-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_RomanNumeralAnnotation-20>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_RangeAnnotation-20>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_MeasurementAnnotation-20>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_LST-7>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_PRT-7>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_NewlineToken-11>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_RangeAnnotation-23>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_NumToken-12>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_metamap_uima_ts_Phrase-4>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_metamap_uima_ts_Phrase-5>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_AnnotationBase-3>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_tcas_Annotation-5>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_tcas_Annotation-6>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_tcas_Annotation-7>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_Sofa-8>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_Sofa-10>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_NonEmptyIntegerList-5>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_StringList-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_NonEmptyStringList-4>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_NonEmptyStringList-6>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_Number-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_Number-3>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_EmptyFloatList-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_IntegerList-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_ListBase-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_FSList-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_FloatList-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_Paragraph>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_temporary_assertion_AssertionCuePhraseAnnotation-13>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_temporary_assertion_AssertionCuePhraseAnnotation-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_SemanticArgument-10>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_SemanticArgument-11>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_Element-15>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_structured_Demographics-12>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textspan_Sentence-11>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_Predicate-11>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textspan_ListEntry-3>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_ConllDependencyNode-17>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_util_Pairs-5>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.uima_cas_Double-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_Affects-13>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_TemporalTextRelation-13>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_ProcedureMethodModifier-24>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_LabEstimatedModifier-24>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_MedicationDuration-17>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_ProcedureMethodModifier-23>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_MedicationDosageModifier-23>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_StanfordDependency-13>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_StopWord-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_Italic-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_DrugCandidate-3>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_TimeOfDayWord-5>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_StandaloneQuantifier-3>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_StandaloneQuantifier-4>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_Probable-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_TimeOfDayWord-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_TimeOfDayWord-3>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_MedicationFrequencyModifier-27>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_SubjectModifier-28>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_NicotineMethod-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_NicotineMethod-3>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_rtf_IllegalXmlCharacter-3>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_rtf_IllegalXmlCharacter-4>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_MedicationRoute-17>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_MedicationStatusChangeModifier-25>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_PolarityModifier-24>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_textsem_CourseModifier-23>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_refsem_BodySide-17>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_ManifestationOf-13>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_IsIndicatedForTextRelation-13>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_syntax_Lemma-8>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_NicotineRelevant-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_BinaryTextRelation-14>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_ManifestationOfTextRelation-14>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_UMLSRelation-14>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.org_apache_ctakes_typesystem_type_relation_DegreeOfTextRelation-14>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.edu_umn_biomedicus_parsing_UDRelation-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_Dependency-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_TimeUnit-2>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <attrs generated init cassis.typesystem.biomedicus_v2_NumberRange-2>:1(<module>)

# %%
# write out new data text
sql = '''
select sofa, note_id from clinical_trial.sofas
where corpus='clinical_trial2'

'''
df = pd.read_sql(sql, engine)
# pull 100 cases 
#rnd = df.apply(lambda x: x.sample(n=100)).uuid.copy()
#print(rnd.dropna())

#sample = rnd.dropna().to_frame().merge(df, how='inner')

print(df.head())

dir_to_write = '/Users/gms/development/nlp/nlpie/data/clinical_trial2/data_in/'
for row in df.itertuples():
    print(row.note_id)
    f = open(dir_to_write + str(row.note_id) +'.txt', 'w')
    f.write(row.sofa)
    f.close()

# %%
# generate cTAKES TUIs
import os, glob
import pymysql
import pandas as pd
import json
#from superjson import json

from sqlalchemy.engine import create_engine
from sqlalchemy.sql import text
from cassis import load_typesystem, load_cas_from_xmi


engine = create_engine('mysql+pymysql://gms:nej123@localhost/concepts', pool_pre_ping=True)

df = pd.read_sql('SELECT ontologyConceptArr, semtypes from concepts.ctakes_concept',con=engine)
df['tui'] = df['ontologyConceptArr'].str.extract(pat = 'tui=(.[^,]+)').apply(lambda s:s.str.replace("'", "")) 

df[['tui', 'semtypes']].drop_duplicates().to_sql("ctakes_tui_semtype", engine, if_exists="replace")
print('Fini!')

# %%
# tui consistency check wrt semantic groups

import pandas as pd
from sqlalchemy.engine import create_engine
sql = '''SELECT tui,
CASE
    WHEN semtypes in ('DiseaseDisorderMention','SignSymptomMention') 
    THEN concat ('DiseaseDisorderMention,SignSymptomMention')
    ELSE semtypes
END as semtypes
FROM concepts.ctakes_tui_semtype;'''

engine = create_engine('mysql+pymysql://gms:nej123@localhost/concepts', pool_pre_ping=True)

new = pd.read_sql(sql, con=engine)

sql = 'select distinct tui, ctakes_name from semantic_groups where ctakes_name is not null'
old = pd.read_sql(sql, con=engine)

test = pd.merge(old, new, how = 'right', left_on=['tui','ctakes_name'], right_on = ['tui','semtypes'], indicator=True) 
test = test[test["_merge"] != "both"]
print((test))

test = pd.merge(old, new, how = 'left', left_on=['tui','ctakes_name'], right_on = ['tui','semtypes'], indicator=True) 
test = test[test["_merge"] != "both"]
print((test))

# %%
# create tables for cTAKES UMLS concept -> mention table
# https://stackoverflow.com/questions/12680754/split-explode-pandas-dataframe-string-entry-to-separate-rows

def mk_ctakes_concepts(sql, table_name):
    import pymysql
    import pandas as pd
    from sqlalchemy.engine import create_engine

    engine = create_engine('mysql+pymysql://gms:nej123@localhost/test', pool_pre_ping=True)

    df = pd.read_sql(sql, engine)

    # MetaMap
    b = pd.DataFrame(df.cuiConcepts.str.split(' ').tolist(), index=df.cuiConcepts).stack()
    b = b.reset_index()[[0, 'cuiConcepts']] # var1 variable is currently labeled 0
    b.columns = ['linked_id', 'cuiConcepts'] # renaming var1
    
    # CTAKES:
     
    #b = pd.DataFrame(df.ontologyConceptArr.str.split(' ').tolist(), index=df.ontologyConceptArr).stack()
    #b = b.reset_index()[[0, 'ontologyConceptArr']] # var1 variable is currently labeled 0
    #b.columns = ['linked_id', 'ontologyConceptArr'] # renaming var1
    

    c = pd.merge(df, b)
   
    c.to_sql(table_name, engine, if_exists="replace") 

    print(c[0:2])

''' TABLES to make
sql = "SELECT * FROM test.met_org_negation"
table_name = 'mm_negation'

mk_ctakes_concepts(sql, table_name)

'''
'''
sql = "SELECT * FROM test.cta_disease"
table_name = 'cTAKES_disease'

mk_ctakes_concepts(sql, table_name)

sql = "SELECT * FROM test.cta_med"
table_name = 'cTAKES_medication'

mk_ctakes_concepts(sql, table_name)


sql = "SELECT * FROM test.cta_proc"
table_name = 'cTAKES_procedure'
mk_ctakes_concepts(sql, table_name)


sql = "SELECT * FROM test.cta_sign_symptom"
table_name = 'cTAKES_sign_symptom'

mk_ctakes_concepts(sql, table_name)

sql = "SELECT * FROM test.cta_anatomical_site"
table_name = 'cTAKES_anatomical_site'

mk_ctakes_concepts(sql, table_name)
'''

# %%
# fix XMI, adding "id" for those with linked features

def add_attribute_sys_type(regexpatterns):
    import re, os, glob, path
    import regex

    #directory_to_parse = '/Users/gms/development/nlp/nlpie/data/amia-2019/i2b2/quarantine/'

    #for fname in glob.iglob("/Users/gms/development/nlp/nlpie/data/amia-2019/i2b2/quarantine/period2/*.txt"):

    for fname in glob.iglob("/Users/gms/development/nlp/nlpie/data/amia-2019/analysis/mipacq/rerun_post_validation/metamap_out/*.txt.xmi"):

        # get filename and use for processed output filename
        t = os.path.basename(fname)
        cd = os.path.dirname(fname)
        u = t.split('.')[0] + '-v2.txt.xmi'
        #print(t, cd)

        #print(t)
        with open(fname) as f:
            with open(cd + '/' + u, 'w') as f2:
                for line in f:
                    for r in regexpatterns:
                        line = re.sub(r, r + ' id="0"', line)
                    f2.write(line)
    

#regexpatterns = [r"refsem:UmlsConcept"]
#regexpatterns = [r"ts2:CuiConcept"]
#regexpatterns = [r"ts2:Negation"]

#add_attribute_sys_type(regexpatterns)

# %%
# test dkpro-cassis
from cassis import *
def test_dkpro(fname, dir_test, ts_test, view_name):
    with open(ts_test + 'TypeSystem.xml', 'rb') as f:
        typesystem = load_typesystem(f)
    init_cassis('biomedicus', typesystem)
    
    with open(dir_test + fname, 'rb') as f:
        cas = load_cas_from_xmi(f, typesystem=typesystem)
    view = cas.get_view(view_name)
    #print([x for x in view.select_all()])
    print([x for x in view.select("biomedicus.v2.TemporalPhrase")]) 
    #print([x for x in view.select("biomedicus.v2.UmlsConcept")]) 
    #print([x for x in view.select("org.apache.ctakes.typesystem.type.refsem.UmlsConcept")]) 
    
    #print([x for x in view.select("org.apache.ctakes.typesystem.type.textsem.DateAnnotation")])
    #print([x for x in view.select("org.metamap.uima.ts.Candidate")])
    
    #print([x for x in view.select("edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA")])

dir_test = '/Users/gms/development/nlp/nlpie/data/clinical_trial/biomedicus_out/'
#view_name = "_InitialView"
view_name = "Analysis"
ts_test = "/Users/gms/development/nlp/nlpie/scripts/jupyter/ensembling/system_annotations/typesystems/biomedicus/"
fname = 'M2.txt.xmi'
                
                
test_dkpro(fname, dir_test, ts_test, view_name)

# %%
# create tables for
# https://stackoverflow.com/questions/12680754/split-explode-pandas-dataframe-string-entry-to-separate-rows

def get_analytical_set(sql):
    import pymysql
    import pandas as pd
    from sqlalchemy.engine import create_engine

    engine = create_engine('mysql+pymysql://gms:nej123@localhost/test', pool_pre_ping=True)

    df = pd.read_sql(sql, engine)
    
    return df

#GENERATE analytical tables
'''
analytical_cui = pd.DataFrame()

sql = "SELECT * FROM test.biomedicus_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])

frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

sql = "SELECT * FROM test.clamp_all_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])

frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

sql = "SELECT * FROM test.ctakes_all_types_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])

frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

sql = "SELECT * FROM test.metamap_all_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])
frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

print(analytical_cui[0:1])
analytical_cui.to_csv('/Users/gms/development/nlp/nlpie/data/amia-2019/output/analytical_cui_mipacq_concepts.csv')
'''

# %%
# clean up cui list in clamp
#df['stridx']=df.index


#print(df[df['cui'].str.contains(',')==True])

#df['new_cui' ] = np.where(df.cui.str.contains(','), df['cui'].str.split(r'\s*,\s*|\s*\.\s*').str[0], df['cui'])

#print(df['cui'])
#print(df[df['cui'].str.contains(',')==False])

#new = df.rename(columns={'cui': 'old_cui', 'new_cui': 'cui'}).copy() 
#new.to_csv('/Users/gms/development/nlp/nlpie/data/amia-2019/output/analytical_cui_mipacq_concepts_new.csv')
#writer = pd.ExcelWriter('/Users/gms/development/nlp/nlpie/data/amia-2019/output/ensemble/merged_metrics.xlsx')
