# %%
# annotation class for UIMA systems
class AnnotationSystems(object):
    """
    CAS XMI Annotations of interest
    
    """
    
    def __init__(self):
        
        """ 
        annotation base types
        """
        
        self.biomedicus_dir = "biomedicus_out/"
        self.biomedicus_types = ["biomedicus.v2.UmlsConcept",
                                 "biomedicus.v2.Negated"]#,
                                 #"biomedicus.v2.Acronym",
                                 #"biomedicus.v2.TemporalPhrase"]
        
        
        self.clamp_dir = "clamp_out/"
        #self.clamp_dir = "Annotated_XMI/"
        self.clamp_types = ["edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA",
                            "edu.uth.clamp.nlp.typesystem.ClampRelationUIMA"]
        
        
        self.ctakes_dir = "ctakes_out/"
        self.ctakes_types = ["org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention",
                             "org.apache.ctakes.typesystem.type.textsem.MedicationMention",
                             "org.apache.ctakes.typesystem.type.textsem.ProcedureMention",
                             "org.apache.ctakes.typesystem.type.textsem.SignSymptomMention",
                             "org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention"]#,
                             #"org.apache.ctakes.typesystem.type.textsem.DateAnnotation",
                             #"org.apache.ctakes.typesystem.type.textsem.MeasurementAnnotation"]
       
        self.metamap_dir = "metamap_out/"
        self.metamap_types = ["org.metamap.uima.ts.Candidate",
                              #"org.metamap.uima.ts.CuiConcept",
                              "org.metamap.uima.ts.Negation"]
                
       
    def get_system_type(self, system):
        
        """
        return system types
        """
        
        if system == "biomedicus":
            view = "Analysis"
            
        else:
            view = "_InitialView"

        if system == 'biomedicus':
            types = self.biomedicus_types
            output = self.biomedicus_dir

        elif system == 'clamp':
            types = self.clamp_types
            output = self.clamp_dir

        elif system == 'ctakes':
            types = self.ctakes_types
            output = self.ctakes_dir

        elif system == 'metamap':
            types = self.metamap_types
            output = self.metamap_dir
            
        return types, view, output
    
annSys = AnnotationSystems()

# extract attributes from cas Annotation object
def get_attribs(v):
    attribs = []
    for sentence in v:
        #print(sentence)
        for s in sentence.__dir__():
            if '__' not in s:
                if s not in attribs:
                    #print(s)
                    attribs.append(s)
                else:
                    break

    return attribs

def get_cols_to_keep(system, t):
    
    if system == 'biomedicus':
        
        if 'Temporal' in t:
            cols_to_keep = ['begin', 'end', 'system', 'note_id', 'corpus',
                            'filename', 'type']
            
        # umlsconcept
        if 'Umls' in t:
            cols_to_keep = ['begin', 'confidence', 'cui', 'end', 'tui',
                            'type', 'system', 'note_id', 'corpus',
                            'filename']

        # acronym
        if 'Acronym' in t:
            cols_to_keep = ['begin', 'end', 'score', 'text', 'type',
                            'system', 'note_id', 'corpus', 'filename']

        # negated
        if 'Negated' in t:
            cols_to_keep = ['begin', 'cueTerms', 'end', 'type', 
                           'system', 'note_id', 'corpus', 'filename']
        
    elif system == 'clamp':
        #NE uima
        if 'NameEntityUIMA' in t:
            cols_to_keep = ['assertion', 'attribute', 'begin',
                           'cui', 'end', 'semanticTag', 'type', 
                           'system', 'note_id', 'corpus', 'filename', 'umlsCuiDesc', 
                            'concept_prob', 'sentence_prob']

        # relation uima: TODO -> deal with named tuples!
        if 'Relation' in t:
#             cols_to_keep = ['attr1', 'attr2', 'attr3', 'attr4', 'attribute', 'cui', 'entFrom', 'entTo',
#                            'semanticTag', 'type', 'xmiID', 'system', 'note_id',
#                            'corpus', 'filename']
            cols_to_keep = ['begin', 'end', 'cui', 'umlsCuiDesc', 'semanticTag', 'type', 'system', 'note_id',
                           'corpus', 'filename', 'src']
        
    elif system == 'ctakes':
        # disease
        if 'Disease' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end', 'historyOf', 
                           'ontologyConceptArr', 'polarity', 'type', 'typeID', 'uncertainty',
                           'system', 'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']

        # medication
        if 'Medication' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end',
                           'historyOf', 'ontologyConceptArr', 'polarity',
                           'type', 'uncertainty', 'system',
                           'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']

        # proc
        if 'Procedure' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end',
                           'historyOf', 'ontologyConceptArr', 'polarity',
                           'type', 'uncertainty', 'system',
                           'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']

        # sign
        if 'SignSymptom' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end',
                           'historyOf', 'ontologyConceptArr', 'polarity',
                           'type', 'uncertainty', 'system',
                           'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']

        # anatomy
        if 'Anatomical' in t:
            cols_to_keep = ['begin', 'conditional', 'confidence', 'end',
                           'historyOf', 'ontologyConceptArr', 'polarity',
                           'type', 'uncertainty', 'system',
                           'note_id', 'corpus', 'filename', 'cui', 'tui', 'preferredText']
            
        if 'Date' in t:
            cols_to_keep = ['begin', 'end', 'type', 'confidence', 'historyOf',  
                           'polarity', 'uncertainty', 'corpus', 'note_id', 'filename', 'system']
        
        if 'Measurement' in t:
            cols_to_keep = ['begin', 'end', 'type', 'confidence', 'historyOf',  
                           'polarity', 'uncertainty', 'corpus', 'note_id', 'filename', 'system']
        
    elif system == 'metamap':
        #candidate
        if 'Candidate' in t:
            cols_to_keep = ['begin', 'concept', 'cui', 'end', 'matchedwords',
                           'preferred', 'score', 'semanticTypes', 'type', 'system', 'note_id',
                           'corpus', 'filename']

        #cuiconcept
        if 'CuiConcept' in t:
            cols_to_keep = ['id', 'negExConcept', 'negExCui', 'type', 'xmiID',
                           'system', 'note_id', 'corpus', 'filename']

        #negation
        if 'Negation' in t:
            cols_to_keep = ['begin', 'cuiConcepts', 'end', 'cui', 'cuiConcept',
                           'ncSpans', 'negTrigger', 'negType',
                           'type', 'system', 'note_id', 'corpus', 'filename']
    
    else:
        cols_to_keep = []

    return cols_to_keep

# %%
def init_cassis(system, typesystem):
   
    #tic=timeit.default_timer() 

    print(system)

    # types for metamap

    if system == 'metamap':
        t = typesystem.create_type(name='org.apache.uima.examples.SourceDocumentInformation', supertypeName='uima.tcas.Annotation')
        typesystem.add_feature(t, name='uri', rangeTypeName='uima.cas.String')
        typesystem.add_feature(t, name="offsetInSource", rangeTypeName="uima.cas.Integer")
        typesystem.add_feature(t, name="documentSize", rangeTypeName="uima.cas.Integer")
        typesystem.add_feature(t, name="lastSegment", rangeTypeName="uima.cas.Integer")

    # features for ctakes

    if system == 'ctakes':
        t = typesystem.get_type('org.apache.ctakes.typesystem.type.structured.Metadata')
        typesystem.add_feature(t, name='patientIdentifier', rangeTypeName='uima.cas.String')
        
        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.DiseaseDisorderMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.SignSymptomMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.MedicationMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.ProcedureMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

        t = typesystem.get_type('org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention')
        typesystem.add_feature(t, name='id', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='ontologyConceptArr', rangeTypeName='uima.cas.FSArray', elementType='org.apache.ctakes.typesystem.type.refsem.UmlsConcept')
        typesystem.add_feature(t, name='subject', rangeTypeName='uima.cas.String')
        #typesystem.add_feature(t, name='typeID', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='discoveryTechnique', rangeTypeName='uima.cas.Integer')
        #typesystem.add_feature(t, name='confidence', rangeTypeName='uima.cas.Double')
        typesystem.add_feature(t, name='polarity', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='uncertainty', rangeTypeName='uima.cas.Integer')
        typesystem.add_feature(t, name='conditional', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='generic', rangeTypeName='uima.cas.Boolean')
        typesystem.add_feature(t, name='historyOf', rangeTypeName='uima.cas.Integer')

# %%
# sofa -> db
def write_sofa(u):
    d = {}
    d["note_id"] = str(u)
    d["sofa"] = view.sofa_string
    d["corpus"] = corpus

    # does it exist?
    if engine.dialect.has_table(engine, "sofas"):
        sql = text("SELECT * FROM test.sofas WHERE note_id = :e1")
        resp = engine.execute(sql, e1=u).fetchall()
    else:
        resp = []

    if len(resp) == 0:            
        #pd.DataFrame(d, index=[0]).to_sql("sofas", engine, if_exists="append")  
        pd.DataFrame(d, index=[0]).to_sql("sofas", engine, if_exists="append")  
        

def get_dict(keys, sentence, d):
    for i in range(len(keys)):
        key = keys[i]
        val = sentence.__getattribute__(keys[i])
        d[key] = val
    return d

def add_keys(df, system, t, u, corpus, fname):
    df["system"] = system
    df["type"] = t
    df["note_id"] = u
    df["corpus"] = corpus
    df["filename"] = fname
    
    return df

# %%
#%%time
# parse system annotations
def main():
    import os, glob
    import pymysql
    import pandas as pd
    import json
    from sqlalchemy.engine import create_engine
    from sqlalchemy.sql import text
    from cassis import load_typesystem, load_cas_from_xmi

    # connection string
    engine = create_engine('mysql+pymysql://gms:nej123@localhost/mhealth', pool_pre_ping=True)
    systems = ["metamap", "ctakes", "biomedicus", "clamp"]
    #systems = ['metamap']
    
    corpora = ["fairview"]
    parse_to_sql = True
    
    if parse_to_sql:
        
        for corpus in corpora:
            print("CORPUS:", corpus)

            for system in systems:

                print("SYSTEM:", system)

                types, view_, output = annSys.get_system_type(system)
                
                dir_test = '/Users/gms/development/nlp/nlpie/scripts/jupyter/ensembling/system_annotations/typesystems/' + system + '/'

                with open(dir_test + 'TypeSystem.xml', 'rb') as f:
                    typesystem = load_typesystem(f)
                
                init_cassis(system, typesystem)
                
                # parse directory
                if corpus in ["i2b2", "mipacq"]:
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/ensembling-u01/' + corpus + '/rerun-november-2019/' +  system + '_out/' #data_to_analyze/all/'
                
                elif corpus == 'fairview':
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/ensembling-u01/' + corpus + '/system_annotations/data_in_preprocessed/' +  system + '_out/'#data_to_analyze/all/'
               
                elif 'clinical_trial' in corpus:
                    # if parsing gold standard, change to_sql below to ensure proper target directory
                    #directory_to_parse = '/Users/gms/development/nlp/nlpie/data/clinical_trial2/' +  system + '_out/'
                    #directory_to_parse = '/Users/gms/development/nlp/nlpie/data/clinical_trial2/gold_standard/'
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/clinical_trial2/bert-output/'
                else:
                    directory_to_parse = '/Users/gms/development/nlp/nlpie/data/mimic/'
                    
                print(directory_to_parse)

                for fname in glob.glob(directory_to_parse + '/0002204202.txt.txt.xmi'):
                #for fname in glob.glob(directory_to_parse + '/527982345.txt.xmi'):

                    file = os.path.basename(fname)
                    u = file.split('.')[0]

                    print(u)

                    # load cas
                    with open(directory_to_parse + file, 'rb') as f:
                        cas = load_cas_from_xmi(f, typesystem=typesystem)

                    # load view
                    view = cas.get_view(view_)
                    
                    # write dofa object here:
                    #write_sofa(u)

                    for t in types:
                        print("TYPE:", t)
                       
                        # get list for filtering df
                        cols_to_keep = get_cols_to_keep(system, t)
                        
                        attribs = get_attribs(view.select(t))
                        x = t.split('.')
                        table_name = system[0:3] + '_' + x[0] + '_' + x[len(x)-1]

                        # Annotation object -> dataframe
                        def get_df(v, attribs):
                            df = pd.DataFrame()

                            # only parse if type exists in file
                            if view.select(t):
                                for sentence in view.select(t):
                                    
                                    d = dict()
                                    if t == 'org.metamap.uima.ts.Negation':
                                        keys = ['cuiConcepts', 'ncSpans', 'negTrigger', 'negType']
                                        d = get_dict(keys, sentence, d)

                                        if len(d['cuiConcepts']) == len(d['ncSpans']) and len(d['cuiConcepts']) == 1:
                                            print('equal:', 
                                                  d['cuiConcepts'][0].negExCui, 
                                                  d['cuiConcepts'][0].negExConcept, 
                                                  d['ncSpans'][0].begin, 
                                                  d['ncSpans'][0].end)
                                            
                                        elif len(d['cuiConcepts']) > len(d['ncSpans']) and len(d['ncSpans']) == 1:
                                            for x in range(len(d['cuiConcepts'])):
                                                print('cui gt:', 
                                                      d['cuiConcepts'][x].negExCui, 
                                                      d['cuiConcepts'][x].negExConcept,
                                                      d['ncSpans'][0].begin,
                                                      d['ncSpans'][0].end)
                                        elif len(d['cuiConcepts']) < len(d['ncSpans']) and len(d['cuiConcepts']) == 1:
                                            for x in range(len(d['ncSpans'])):
                                                print('cui lt:', x,
                                                      d['cuiConcepts'][0].negExCui, 
                                                      d['cuiConcepts'][0].negExConcept,
                                                      d['ncSpans'][x].begin,
                                                      d['ncSpans'][x].end)
                                        else:
                                            print('Error: MetaMap Negation')
                                        print('mm neg',
                                              d['cuiConcepts'][0].negExCui)
                                    
                                    elif t == 'edu.uth.clamp.nlp.typesystem.ClampRelationUIMA':
                                        keys = ['semanticTag', 'entTo', 'entFrom']
                                        d = get_dict(keys, sentence, d)
                                        
                                        if d['semanticTag'] == 'NEG_Of':
                                            #print(d['entTo'], '\n', d['entFrom'])
                                            attribute =  json.loads(d['entFrom'].attribute)
                                            if 'umlsCuiDesc' in attribute:
                                                print('clamp neg',
                                                      d['entFrom'].cui.split()[0], 
                                                      attribute['umlsCuiDesc'],
                                                      d['entFrom'].begin,
                                                      d['entFrom'].end)
                                        
                                    elif t == 'biomedicus.v2.Negated':
                                        keys = ['begin', 'end']
                                        for i in range(len(keys)):
                                            key = keys[i]
                                            val = sentence.__getattribute__(keys[i])
                                            d[key] = val
                                        
                                        print('b9 neg:',
                                              d['begin'])
                                        
                                    elif t == 'biomedicus.v2.UmlsConcept':
                                        keys = ['begin', 'end', 'cui', 'tui', 'confidence']
                                        d = get_dict(keys, sentence, d)
                                        
                                        print('b9 concept',
                                              d['cui'])
                                    
                                    elif t == 'edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA':
                                        keys = ['assertion', 'cui', 'begin', 'end', 'attribute', 'semanticTag']
                                        d = get_dict(keys, sentence, d)
                                        
                                        if 'attribute' in d and d['attribute']:
                                            attribute =  json.loads(d['attribute'])
                                            if d['assertion'] == 'present':
                                                if 'umlsCuiDesc' in attribute:
                                                    print('clamp concept:', 
                                                          attribute['sentence_prob'], 
                                                          attribute['umlsCuiDesc'],
                                                          attribute['concept_prob'],
                                                          d['begin'],
                                                          d['end'],
                                                          d['semanticTag'])
                                                    
                                    elif t == 'org.apache.ctakes.typesystem.type.textsem.AnatomicalSiteMention': #'Mention' in t:
                                        keys = ['begin', 'conditional', 'confidence', 'end', 'historyOf', 'ontologyConceptArr', 'polarity', 
                                                'uncertainty']
                                        d = get_dict(keys, sentence, d)
                                        
                                        for x in range(len(d['ontologyConceptArr'])):
                                                print('ctakes concepts:', 
                                                      d['ontologyConceptArr'][x].cui,
                                                      d['ontologyConceptArr'][x].tui,
                                                      d['ontologyConceptArr'][x].preferredText)
                                                
                                    elif t == 'org.metamap.uima.ts.Candidate':
                                        keys =  ['begin', 'concept', 'cui', 'end',
                                                 'preferred', 'score', 'semanticTypes', 'matchedwords']
                                        d = get_dict(keys, sentence, d)
                                            
                                        print('mm concepts:', 
                                              " ".join(d['semanticTypes']),
                                              " ".join(d['matchedwords']))
                                                                               

                        annotations = get_df(view.select(t), attribs)

#                         # write to database
                            
#                             #annotations = annotations[cols_to_keep]
#                             #annotations.to_sql(table_name + '_reference', engine, if_exists="append") 
#                             #annotations.to_sql(table_name + '_bert', engine, if_exists="append") 
#                             #annotations.to_csv('~/Desktop/test.csv')
#                             #annotations.to_sql(table_name, engine, if_exists="append") 
#                             #print(annotations.head())    
    # write out annotations for non-cui tables
    else:
        
        sys_ann_other = pd.DataFrame()
        for system in systems:
                
            types, view_, output = annSys.get_system_type(system)
            print("SYSTEM:", system)
           
            for t in types:

                x = t.split('.')
                table_name = system[0:3] + '_' + x[0] + '_' + x[len(x)-1]

                sql = "SELECT * FROM test." + table_name 
                df = pd.read_sql(sql, engine)

                cols_to_keep = ['begin', 'end', 'type', 'system', 'note_id', 'corpus', 'filename']
                #print(system, t, table_name, list(df[cols_to_keep].columns.values))
                
                frames = [ sys_ann_other, df[cols_to_keep] ]
                sys_ann_other = pd.concat(frames, ignore_index=True)
        
        print(sys_ann_other.drop_duplicates())
        sys_ann_other.drop_duplicates().to_csv('/Users/gms/development/nlp/nlpie/data/amia-2019/output/analytical_' + corpus + '.csv')

    print("done!")

if __name__ == '__main__':
    main()
# Out:
# CORPUS: fairview
# SYSTEM: metamap
# metamap
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/metamap_out/
# SYSTEM: ctakes
# ctakes
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/ctakes_out/
# SYSTEM: biomedicus
# biomedicus
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/biomedicus_out/
# SYSTEM: clamp
# clamp
# /Users/gms/development/nlp/nlpie/data/ensembling-u01/fairview/system_annotations/data_in_preprocessed/clamp_out/
# 0002204202
# TYPE: edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA
# clamp concept: 0.532 trivalent influenza vaccine 0.545 353 361 treatment
# clamp concept: 0.96 Vital (qualifier value) 0.994 369 375 test
# clamp concept: 0.537 Influenza vaccination 0.687 497 519 treatment
# clamp concept: 0.953 Influenza vaccine injection 0.5mL 0.987 588 616 treatment
# clamp concept: 0.419 Allergy Specialty 0.508 825 832 problem
# clamp concept: 0.763 Guillain-Barre Syndrome 0.826 884 907 problem
# clamp concept: 0.418 Moderate (severity modifier) 0.718 928 936 problem
# clamp concept: 0.418 Denial about illness severity 0.701 940 954 problem
# clamp concept: 0.876 Prophylactic vaccination against the common cold 0.93 964 975 treatment
# clamp concept: 0.979 Vaccines 0.979 1119 1130 treatment
# clamp concept: 0.995 Chest Pain 0.998 3044 3054 problem
# clamp concept: 0.901 Vitamed Prenatal Formula 0.931 3504 3509 treatment
# clamp concept: 0.811 Need for immunization against unspecified infectious disease 0.997 4119 4143 treatment
# clamp concept: 0.811 Vaccination 0.814 4148 4159 treatment
# clamp concept: 0.434 Influenza virus vaccine 0.844 4194 4203 problem
# clamp concept: 0.716 Hypothyroidism 0.973 4286 4300 problem
# clamp concept: 0.638 Acquired scoliosis 0.788
problem
# clamp concept: 0.926 Lumbar spinal fusion 0.927 65088 65101 treatment
# clamp concept: 0.981 Fused structure 0.983 65202 65208 treatment
# clamp concept: 0.515 Urge Incontinence 0.997 65227 65244 problem
# clamp concept: 0.586 Amnesia 0.987 65375 65386 problem
# clamp concept: 0.983 Magnetic Resonance Imaging 0.994 65461 65464 test
# clamp concept: 0.964 Atrophic 0.964 65514 65521 problem
# clamp concept: 0.632 Hyperlipoproteinemias 0.999 65578 65592 problem
# clamp concept: 0.418 Neck Pain 0.688 65652 65663 problem
# clamp concept: 0.927 Pretended abnormality of gait 0.985 65726 65745 problem
# clamp concept: 0.589 Gait, Unsteady 0.885 65800 65816 problem
# clamp concept: 0.995 Peripheral Neuropathy 0.997 65886 65907 problem
# clamp concept: 0.981 Chronic low back pain 0.989 65970 65991 problem
# clamp concept: 0.999 Chronic pain 0.999 66056 66068 problem
# clamp concept: 0.564 Bone structure of sacrum 0.982 66101 66107 treatment
# clamp concept: 0.548 Low Back Pain 0.711 66185 66192 problem
# clamp concept: 0.986 Sulfonamide Anti-Infective Agents 0.999 66322 66333 treatment
# clamp concept: 0.994 Exanthema 0.994 66384 66388 problem
# clamp concept: 0.383 Electrocardiography 0.863 66563 66580 test
# clamp concept: 0.98 Electrocardiogram 0.997 66684 66687 test
# clamp concept: 0.97 Atrial Fibrillation by ECG Finding 0.97 67032 67051 problem
# clamp concept: 0.353 Electrocardiography 0.785 67254 67271 test
# clamp concept: 0.97 Atrial Fibrillation by ECG Finding 0.97 67386 67405 problem
# clamp concept: 0.764 Chronic back pain 1.0 67718 67735 problem
# clamp concept: 0.764 Elective Surgical Procedures 0.999 67749 67770 treatment
# clamp concept: 0.986 Back surgery 0.986 67799 67811 treatment
# clamp concept: 0.986 Chronic back pain 1.0 67816 67833 problem
# clamp concept: 0.937 Atrial fibrillation with rapid ventricular response 0.958 67871 67897 problem
# clamp concept: 0.988 Ischemia co-occurrent and due to increased oxygen demand 0.992 67957 67972 problem
# clamp concept: 0.426 Echocardiography 0.996 68016 68030 test
# clamp concept: 0.426 Elongation Factor 1delta 0.92 68042 68044 test
# clamp concept: 0.426 Diastolic dysfunction 0.591 68093 68114 problem
# clamp concept: 0.957 Right ventricular systolic pressure level 0.996 68175 68210 test
# clamp concept: 0.996 Aortic sclerosis 1.0 68295 68311 problem
# clamp concept: 0.832 Troponin 0.998 68337 68346 test
# clamp concept: 0.832 Troponin 0.952 68356 68364 test
# clamp concept: 0.832 Troponin 0.876 68386 68394 test
# clamp concept: 0.461 Back surgery 0.567 68459 68471 treatment
# clamp concept: 0.986 Atrial Fibrillation by ECG Finding 1.0 68618 68637 problem
# clamp concept: 0.96 Atrial Fibrillation by ECG Finding 0.989 68745 68764 problem
# clamp concept: 0.973 radiation therapy bolus step 0.983 68819 68826 treatment
# clamp concept: 0.502 Asymptomatic 0.506 69140 69152 problem
# clamp concept: 0.666 Atrial Fibrillation 0.96 69600 69619 test
# clamp concept: 0.666 Thyroid function tests abnormal 0.998 69632 69656 test
# clamp concept: 0.666 Echocardiography 0.996 69691 69705 test
# clamp concept: 0.666 Troponin 0.935 69732 69741 test
# clamp concept: 0.883 Ischemia co-occurrent and due to increased oxygen demand 0.926 69830 69845 problem
# clamp concept: 0.909 angiogram 0.977 69962 69971 test
# clamp concept: 0.909 Mild chronic obstructive pulmonary disease 0.934 70005 70017 problem
# clamp concept: 0.973 Slurred speech 0.999 70352 70366 problem
# clamp concept: 0.775 Pharmaceutical Preparations 0.996 70624 70635 treatment
# clamp concept: 0.889 Depersonalization 0.91 79836 79848 problem
# clamp concept: 0.987 Surgery of the Hand - Plastic Surgery Physicians 0.988 79859 79870 treatment
# clamp concept: 0.891 Chronic low back pain 0.998 80200 80221 problem
# clamp concept: 0.891 Sacral fusion 0.906 80241 80254 treatment
# clamp concept: 0.977 Gait, Unsteady 0.981 80260 80276 problem
# clamp concept: 0.977 Peripheral Neuropathy 0.999 80298 80319 problem
# clamp concept: 0.999 Hyperlipoproteinemias 1.0 80325 80339 problem
# clamp concept: 0.995 Amnesia 0.995 80345 80356 problem
# clamp concept: 0.969 Hypothyroidism 0.969 80362 80376 problem
# clamp concept: 0.987 Multiple closed anterior-posterior compression fractures of pelvis 0.998 80417 80447 problem
# clamp concept: 0.936 Acquired scoliosis 0.97 80453 80462 problem
# clamp concept: 0.936 Lumbar spinal fusion 0.973 80476 80489 treatment
# clamp concept: 0.989 Spondylosis 0.99 80495 80506 problem
# clamp concept: 0.998 Urge Incontinence 0.999 80512 80529 problem
# clamp concept: 0.73 Exercise stress test 0.996 80585 80599 test
# clamp concept: 0.615 CT angiography of pelvis 0.998 80725 80737 test
# clamp concept: 0.154 angiogram 0.995 80865 80874 test
# clamp concept: 0.999 Gastroesophageal reflux disease 1.0 81065 81096 problem
# clamp concept: 0.967 Chest Pain 0.995 81292 81302 problem
# clamp concept: 0.995 Sleeplessness 0.999 81360 81368 problem
# clamp concept: 0.987 EUCERIN LOTION,TOP 1.0 81508 81522 treatment
# clamp concept: 0.794 Vicodin 1.0 81675 81682 treatment
# clamp concept: 0.794 Pain Clinics 0.797 81696 81700 problem
# clamp concept: 0.469 Blood Pressure 0.995 82000 82014 test
# clamp concept: 0.469 heart rate 0.978 82029 82039 test
# clamp concept: 0.469 Gases, blood, O2 saturation only, by direct measurement, except pulse oximetry 0.992 82057 82064 test
# clamp concept: 0.937 Auscultation 0.947 82222 82234 test
# clamp concept: 0.556 Non-tender 0.72 82326 82335 problem
# clamp concept: 0.536 Cytidine Monophosphate 0.986 82489 82492 test
# clamp concept: 0.536 ferrichrome A potassium salt 0.928 82512 82523 test
# clamp concept: 0.723 Complete Blood Count 0.999 82561 82564 test
# clamp concept: 0.723 White Blood Cell Count procedure 0.975 82573 82584 test
# clamp concept: 0.723 Hemoglobin 0.998 82593 82603 test
# clamp concept: 0.723 Platelet Count measurement 0.747 82635 82649 test
# clamp concept: 0.986 Troponin 0.988 82683 82691 test
# clamp concept: 0.997 Thyrotropin 0.999 82706 82709 test
# clamp concept: 0.509 Urinalysis 0.996 82723 82733 test
# clamp concept: 0.697 unsatisfactory echocardiography exam 0.999 82805 82823 test
# clamp concept: 0.952 Back surgery 0.998 83062 83074 treatment
# clamp concept: 0.952 Atrial Fibrillation by ECG Finding 1.0 83080 83099 problem
# clamp concept: 0.952 Atrial fibrillation with rapid ventricular response 0.958 83105 83131 problem
# clamp concept: 0.957 Atrial Fibrillation by ECG Finding 1.0 83136 83155 problem
# clamp concept: 0.957 Atrial fibrillation with rapid ventricular response 0.958 83161 83187 problem
# TYPE: edu.uth.clamp.nlp.typesystem.ClampRelationUIMA
# clamp neg C0033213 Problem 5203 5211
# clamp neg C1290905 Discrepancy 8830 8843
# clamp neg C0231303 Distress 12710 12718
# clamp neg C3887532 Ulceration 12820 12826
# clamp neg C0221198 Lesion 12830 12837
# clamp neg C0497156 Lymphadenopathy 12847 12857
# clamp neg C0332514 Asymmetry 12862 12871
# clamp neg C0240859 Basilar Rales 12961 12966
# clamp neg C1306372 Mass, a measure of quantity of matter 13010 13016
# clamp neg C0234234 Tender 13018 13028
# clamp neg C0149741 nipple discharge 13032 13048
# clamp neg C0497156 Lymphadenopathy 13084 13094
# clamp neg C0223600 Structure of third sacral vertebra 13142 13144
# clamp neg C3853525 S4 heart sound 13148 13150
# clamp neg C0018808 Heart murmur 13155 13161
# clamp neg C0018808 Heart murmur 13155 13161
# clamp neg C0231756 Patellar tap 13163 13168
# clamp neg C0032230 Pleural Rub 13172 13175
# clamp neg C0006318 Bruit 13209 13215
# clamp neg C0006318 Bruit 13209 13215
# clamp neg C0520960 Non-tender 13300 13309
# clamp neg C0019214 Hepatosplenomegaly 13319 13337
# clamp neg C1306372 Mass, a measure of quantity of matter 13341 13347
# clamp neg C1306372 Mass, a measure of quantity of matter 13413 13419
# clamp neg C0600083 Discharge, Body Substance, Sample 13423 13432
# clamp neg C0005956 Bone Marrow Diseases 19552 19562
# clamp neg C0033213 Problem 20734 20742
# clamp neg C0005956 Bone Marrow Diseases 26973 26983
# clamp neg C1290905 Discrepancy 29158 29171
# clamp neg C0011168 Deglutition Disorders 30633 30642
# clamp neg C0687152 Does cough 30856 30861
# clamp neg C0421188 Cardiac drug side effects 31072 31084
# clamp neg C0231303 Distress 33560 33568
# clamp neg C3887532 Ulceration 33630 33636
# clamp neg C0221198 Lesion 33640 33647
# clamp neg C0497156 Lymphadenopathy 33657 33667
# clamp neg C0332514 Asymmetry 33672 33681
# clamp neg C0240859 Basilar Rales 33771 33776
# clamp neg C0086132 Depressive Symptoms 34878 34886
# clamp neg C0086132 Depressive Symptoms 35594 35602
# clamp neg C0033213 Problem 41934 41942
# clamp neg C0032227 Pleural effusion disorder 53371 53388
# clamp neg C0086132 Depressive Symptoms 59128 59136
# clamp neg C0030252 Palpitations 59161 59173
# clamp neg C0008031 Chest Pain 59353 59363
# clamp neg C0030252 Palpitations 59365 59377
# clamp neg C0242936 Pain Clinics 59709 59713
# clamp neg C0018808 Heart murmur 60091 60097
# clamp neg C0013604 Edema 60134 60139
# clamp neg C0149721 Left Ventricular Hypertrophy 60237 60240
# clamp neg C0005956 Bone Marrow Diseases 64506 64516
# clamp neg C0033213 Problem 65567 65575
# clamp neg C0678234 Stenosis Morphology 68320 68328
# clamp neg C0267057 Alkaline reflux disease 69566 69580
# clamp neg C0008031 Chest Pain 70043 70053
# clamp neg C0008031 Chest Pain 70043 70053
# clamp neg C0008031 Chest Pain 70134 70144
# clamp neg C0748355 Acute respiratory distress 71892 71906
# clamp neg C0240962 Scleral icterus 71924 71939
# clamp neg C0018808 Heart murmur 72064 72071
# clamp neg C0032230 Pleural Rub 72073 72077
# clamp neg C0232200 Gallop rhythm 72081 72088
# clamp neg C0013604 Edema 72163 72168
# clamp neg C0010520 Cyanosis 72206 72214
# clamp neg C0008031 Chest Pain 79937 79947
# clamp neg C0027497 Nausea 80151 80157
# clamp neg C0042965 Vomitus 80162 80170
# clamp neg C0748355 Acute respiratory distress 82143 82157
# clamp neg C0240962 Scleral icterus 82175 82190
# clamp neg C0010520 Cyanosis 82375 82383
# clamp neg C0221096 Club, device 82387 82395
# clamp neg C0013604 Edema 82441 82446
# clamp neg C0031039 Pericardial effusion 82923 82943
# clamp neg C1290905 Discrepancy 85298 85311
# clamp neg C0231242 Complicated 86242 86255
# clamp neg C0033213 Problem 88355 88363
# clamp neg C0005956 Bone Marrow Diseases 88967 88977
# clamp neg C0424755 Fever symptoms (finding) 90891 90896
# clamp neg C0008031 Chest Pain 91098 91108
# clamp neg C0027497 Nausea 91160 91166
# clamp neg C1762617 Weak 91333 91341
# clamp neg C0019080 Hemorrhage 91403 91420
# clamp neg C0231303 Distress 91592 91600
# clamp neg C3887532 Ulceration 91661 91667
# clamp neg C0221198 Lesion 91671 91678
# clamp neg C0497156 Lymphadenopathy 91688 91698
# clamp neg C0332514 Asymmetry 91703 91712
# clamp neg C0240859 Basilar Rales 91802 91807
# clamp neg C0223600 Structure of third sacral vertebra 91875 91877
# clamp neg C3853525 S4 heart sound 91881 91883
# clamp neg C0018808 Heart murmur 91891 91897
# clamp neg C0018808 Heart murmur 91891 91897
# clamp neg C0231756 Patellar tap 91899 91904
# clamp neg C0032230 Pleural Rub 91908 91911
# clamp neg C1306372 Mass, a measure of quantity of matter 92011 92017
# clamp neg C0149721 Left Ventricular Hypertrophy 92245 92248
# clamp neg C0033213 Problem 96982 96990
# clamp neg C0033213 Problem 109251 109259
# done!

# %%
# write out new data text
sql = '''
select sofa, note_id from clinical_trial.sofas
where corpus='clinical_trial2'

'''
df = pd.read_sql(sql, engine)
# pull 100 cases 
#rnd = df.apply(lambda x: x.sample(n=100)).uuid.copy()
#print(rnd.dropna())

#sample = rnd.dropna().to_frame().merge(df, how='inner')

print(df.head())

dir_to_write = '/Users/gms/development/nlp/nlpie/data/clinical_trial2/data_in/'
for row in df.itertuples():
    print(row.note_id)
    f = open(dir_to_write + str(row.note_id) +'.txt', 'w')
    f.write(row.sofa)
    f.close()

# %%
# generate cTAKES TUIs
import os, glob
import pymysql
import pandas as pd
import json
#from superjson import json

from sqlalchemy.engine import create_engine
from sqlalchemy.sql import text
from cassis import load_typesystem, load_cas_from_xmi


engine = create_engine('mysql+pymysql://gms:nej123@localhost/concepts', pool_pre_ping=True)

df = pd.read_sql('SELECT ontologyConceptArr, semtypes from concepts.ctakes_concept',con=engine)
df['tui'] = df['ontologyConceptArr'].str.extract(pat = 'tui=(.[^,]+)').apply(lambda s:s.str.replace("'", "")) 

df[['tui', 'semtypes']].drop_duplicates().to_sql("ctakes_tui_semtype", engine, if_exists="replace")
print('Fini!')

# %%
# tui consistency check wrt semantic groups

import pandas as pd
from sqlalchemy.engine import create_engine
sql = '''SELECT tui,
CASE
    WHEN semtypes in ('DiseaseDisorderMention','SignSymptomMention') 
    THEN concat ('DiseaseDisorderMention,SignSymptomMention')
    ELSE semtypes
END as semtypes
FROM concepts.ctakes_tui_semtype;'''

engine = create_engine('mysql+pymysql://gms:nej123@localhost/concepts', pool_pre_ping=True)

new = pd.read_sql(sql, con=engine)

sql = 'select distinct tui, ctakes_name from semantic_groups where ctakes_name is not null'
old = pd.read_sql(sql, con=engine)

test = pd.merge(old, new, how = 'right', left_on=['tui','ctakes_name'], right_on = ['tui','semtypes'], indicator=True) 
test = test[test["_merge"] != "both"]
print((test))

test = pd.merge(old, new, how = 'left', left_on=['tui','ctakes_name'], right_on = ['tui','semtypes'], indicator=True) 
test = test[test["_merge"] != "both"]
print((test))

# %%
# create tables for cTAKES UMLS concept -> mention table
# https://stackoverflow.com/questions/12680754/split-explode-pandas-dataframe-string-entry-to-separate-rows

def mk_ctakes_concepts(sql, table_name):
    import pymysql
    import pandas as pd
    from sqlalchemy.engine import create_engine

    engine = create_engine('mysql+pymysql://gms:nej123@localhost/test', pool_pre_ping=True)

    df = pd.read_sql(sql, engine)

    # MetaMap
    b = pd.DataFrame(df.cuiConcepts.str.split(' ').tolist(), index=df.cuiConcepts).stack()
    b = b.reset_index()[[0, 'cuiConcepts']] # var1 variable is currently labeled 0
    b.columns = ['linked_id', 'cuiConcepts'] # renaming var1
    
    # CTAKES:
     
    #b = pd.DataFrame(df.ontologyConceptArr.str.split(' ').tolist(), index=df.ontologyConceptArr).stack()
    #b = b.reset_index()[[0, 'ontologyConceptArr']] # var1 variable is currently labeled 0
    #b.columns = ['linked_id', 'ontologyConceptArr'] # renaming var1
    

    c = pd.merge(df, b)
   
    c.to_sql(table_name, engine, if_exists="replace") 

    print(c[0:2])

''' TABLES to make
sql = "SELECT * FROM test.met_org_negation"
table_name = 'mm_negation'

mk_ctakes_concepts(sql, table_name)

'''
'''
sql = "SELECT * FROM test.cta_disease"
table_name = 'cTAKES_disease'

mk_ctakes_concepts(sql, table_name)

sql = "SELECT * FROM test.cta_med"
table_name = 'cTAKES_medication'

mk_ctakes_concepts(sql, table_name)


sql = "SELECT * FROM test.cta_proc"
table_name = 'cTAKES_procedure'
mk_ctakes_concepts(sql, table_name)


sql = "SELECT * FROM test.cta_sign_symptom"
table_name = 'cTAKES_sign_symptom'

mk_ctakes_concepts(sql, table_name)

sql = "SELECT * FROM test.cta_anatomical_site"
table_name = 'cTAKES_anatomical_site'

mk_ctakes_concepts(sql, table_name)
'''

# %%
# fix XMI, adding "id" for those with linked features

def add_attribute_sys_type(regexpatterns):
    import re, os, glob, path
    import regex

    #directory_to_parse = '/Users/gms/development/nlp/nlpie/data/amia-2019/i2b2/quarantine/'

    #for fname in glob.iglob("/Users/gms/development/nlp/nlpie/data/amia-2019/i2b2/quarantine/period2/*.txt"):

    for fname in glob.iglob("/Users/gms/development/nlp/nlpie/data/amia-2019/analysis/mipacq/rerun_post_validation/metamap_out/*.txt.xmi"):

        # get filename and use for processed output filename
        t = os.path.basename(fname)
        cd = os.path.dirname(fname)
        u = t.split('.')[0] + '-v2.txt.xmi'
        #print(t, cd)

        #print(t)
        with open(fname) as f:
            with open(cd + '/' + u, 'w') as f2:
                for line in f:
                    for r in regexpatterns:
                        line = re.sub(r, r + ' id="0"', line)
                    f2.write(line)
    

#regexpatterns = [r"refsem:UmlsConcept"]
#regexpatterns = [r"ts2:CuiConcept"]
#regexpatterns = [r"ts2:Negation"]

#add_attribute_sys_type(regexpatterns)

# %%
# test dkpro-cassis
from cassis import *
def test_dkpro(fname, dir_test, ts_test, view_name):
    with open(ts_test + 'TypeSystem.xml', 'rb') as f:
        typesystem = load_typesystem(f)
    init_cassis('biomedicus', typesystem)
    
    with open(dir_test + fname, 'rb') as f:
        cas = load_cas_from_xmi(f, typesystem=typesystem)
    view = cas.get_view(view_name)
    #print([x for x in view.select_all()])
    print([x for x in view.select("biomedicus.v2.TemporalPhrase")]) 
    #print([x for x in view.select("biomedicus.v2.UmlsConcept")]) 
    #print([x for x in view.select("org.apache.ctakes.typesystem.type.refsem.UmlsConcept")]) 
    
    #print([x for x in view.select("org.apache.ctakes.typesystem.type.textsem.DateAnnotation")])
    #print([x for x in view.select("org.metamap.uima.ts.Candidate")])
    
    #print([x for x in view.select("edu.uth.clamp.nlp.typesystem.ClampNameEntityUIMA")])

dir_test = '/Users/gms/development/nlp/nlpie/data/clinical_trial/biomedicus_out/'
#view_name = "_InitialView"
view_name = "Analysis"
ts_test = "/Users/gms/development/nlp/nlpie/scripts/jupyter/ensembling/system_annotations/typesystems/biomedicus/"
fname = 'M2.txt.xmi'
                
                
test_dkpro(fname, dir_test, ts_test, view_name)

# %%
# create tables for
# https://stackoverflow.com/questions/12680754/split-explode-pandas-dataframe-string-entry-to-separate-rows

def get_analytical_set(sql):
    import pymysql
    import pandas as pd
    from sqlalchemy.engine import create_engine

    engine = create_engine('mysql+pymysql://gms:nej123@localhost/test', pool_pre_ping=True)

    df = pd.read_sql(sql, engine)
    
    return df

#GENERATE analytical tables
'''
analytical_cui = pd.DataFrame()

sql = "SELECT * FROM test.biomedicus_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])

frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

sql = "SELECT * FROM test.clamp_all_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])

frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

sql = "SELECT * FROM test.ctakes_all_types_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])

frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

sql = "SELECT * FROM test.metamap_all_cui where corpus = 'mipacq'"

print(get_analytical_set(sql)[0:1])
frames = [ analytical_cui, get_analytical_set(sql) ]
analytical_cui = pd.concat(frames, ignore_index=True, sort=False) 

print(analytical_cui[0:1])
analytical_cui.to_csv('/Users/gms/development/nlp/nlpie/data/amia-2019/output/analytical_cui_mipacq_concepts.csv')
'''

# %%
# clean up cui list in clamp
#df['stridx']=df.index


#print(df[df['cui'].str.contains(',')==True])

#df['new_cui' ] = np.where(df.cui.str.contains(','), df['cui'].str.split(r'\s*,\s*|\s*\.\s*').str[0], df['cui'])

#print(df['cui'])
#print(df[df['cui'].str.contains(',')==False])

#new = df.rename(columns={'cui': 'old_cui', 'new_cui': 'cui'}).copy() 
#new.to_csv('/Users/gms/development/nlp/nlpie/data/amia-2019/output/analytical_cui_mipacq_concepts_new.csv')
#writer = pd.ExcelWriter('/Users/gms/development/nlp/nlpie/data/amia-2019/output/ensemble/merged_metrics.xlsx')
